# %% [markdown]
# #Model Build - Fast Hyper Parameter Search
# Building and testing models notebook for Google Colab
#
# The gridsearch was taking way too long. This script now includes a function that searches over the hyperparemeters far more rapidly. Its not as thorough but given what we saw last time, it doesnt need to be.
#
# This was primarily used to create optimised models for the weather variables besides temperature.
#
# For more thorough commentary, please see model_build_smooth.
#
#
# Be sure to switch to GPU in the run time

# %%
import pandas as pd
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt
import time
import os

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import InputLayer, LSTM, GRU, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator

from scipy.ndimage import gaussian_filter1d

print(tf.config.list_physical_devices())
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'), PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
#my file path to data on Gdrive
! ls drive/MyDrive/0_neural_net_weather_forecasts_on_cloud/Data
# Out:
# best_temp_model.h5	      results_table_1621583745.csv
# best_temp_smooth_model.h5     results_table_1621688232.csv
# precip_model.h5		      results_table_1621765059.csv
# records_1621964476.csv	      results_table_temp.csv
# records_1621964569.csv	      results_table_temp_smooth.csv
# records_1621966077.csv	      temp_model.h5
# results_table_1621536110.csv  weather_data.csv

# %%
os.chdir('drive/MyDrive/0_neural_net_weather_forecasts_on_cloud/Data')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-71c9e250a0d4> in <module>()
# ----> 1 os.chdir('drive/MyDrive/0_neural_net_weather_forecasts_on_cloud/Data')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'drive/MyDrive/0_neural_net_weather_forecasts_on_cloud/Data'

# %%
df = pd.read_csv('weather_data.csv')

#get time
df['datetime'] = pd.to_datetime(df['datetime'], format='%d/%m/%Y')
df = df.set_index('datetime')

print(df.columns)
# Out:
# Index(['datetimeEpoch', 'tempmax', 'tempmin', 'temp', 'feelslikemax',
#        'feelslikemin', 'feelslike', 'dew', 'humidity', 'precip', 'precipprob',
#        'precipcover', 'preciptype', 'snow', 'snowdepth', 'windgust',
#        'windspeed', 'winddir', 'pressure', 'cloudcover', 'visibility',
#        'solarradiation', 'solarenergy', 'uvindex', 'sunrise', 'sunriseEpoch',
#        'sunset', 'sunsetEpoch', 'moonphase', 'conditions', 'description',
#        'icon', 'stations', 'source', 'tzoffset'],
#       dtype='object')

# %%
#get precip
precip = df['precip']

#split data (Save a week for testing. Train and Validation made in class)
precip_train = precip.iloc[:-7]
precip_test = precip.iloc[-7:]


#inspect
precip_train.iloc[-60:].plot()

# %% [markdown]
# ##Define the model class

# %%
class BuildModel():
    """
    Build a model. Arguments allow one to customise the hyper parameters
    ATTRIBUTES :- 
    length - number of steps in time sequence to feed the rnn
    layers_num - number of rnn layers in model (capped at 3)
    layers_type - select "LSTM" or "GRU"
    units - number of units in rnn layers
    num_step_preds - number of steps/days in time to predict
    dropout - dropout % to be applied to rnn units
    g_filt - gaussian filter for smoothing. Default: no smoothing
    batch_size - number of samples to feed model at a time.
    patience - how many epochs to wait before stopping model after finding good score.
    model_name - file name of model we save. must end in ".h5" eg 'temp_model.h5'
    """
    def __init__(self, model_name, length=10, layers_num=1, layers_type='LSTM',\
                 units=50, dropout=0.0, g_filt=00.1, num_step_preds=1,\
                 epochs=8, batch_size=1, patience=5):
        
        #assertions for input
        assert 0 < layers_num < 4, "1 <= layers_num <= 3"
        assert layers_type in ['LSTM', 'GRU'], "layers_type is LSTM or GRU"
        assert 0 <= dropout < 1, "dropout must be float < 1"
        assert model_name[-3:] == '.h5', "End model_name with '.h5'"
        
        #initialise
        self.model_name = model_name        
        self.length = length
        self.layers_num = layers_num
        self.layers_type = layers_type
        self.units = units
        self.num_step_preds = num_step_preds
        self.dropout = dropout
        self.g_filt = g_filt
        self.epochs = epochs
        self.batch_size = batch_size
        self.n_features = 1
        
        #callbacks
        self.callbacks =[EarlyStopping(monitor='val_loss', patience=patience),\
                         ModelCheckpoint(self.model_name, monitor='val_loss',\
                                         save_best_only=True)]
        
        #BUILD MODEL
        ##inputs
        self.model = Sequential()
        self.model.add(InputLayer(input_shape=(self.length, self.n_features)))
        
        ##add extra layers as required (or not if layers_num = 1)
        for i in range(layers_num - 1):
            self.model.add(eval('{}(units={}, dropout={}, return_sequences=True)'\
                .format(self.layers_type, self.units, self.dropout)))
                
        ##closing rnn layer (do not return squences)
        self.model.add(eval('{}(units={}, dropout={})'\
                .format(self.layers_type, self.units, self.dropout)))
            
        ##Dense output
        self.model.add(Dense(units=self.num_step_preds))
                       
        #compile model
        self.model.compile(optimizer='adam', loss='mse', metrics=['mae'])
    
    def setupData(self, series, val_days=450):
        """
        splits data, scales data, creates generators for the model
        """
        assert val_days > self.length , "val_days must exceed lenght"
        
        #split data into train and validation
        self.train = series.iloc[:-val_days]
        self.validation = series.iloc[-val_days:]
        
        #Apply smoothing filters  
        self.train_smooth = \
             gaussian_filter1d(self.train, self.g_filt)\
                 .reshape(-1,1)
            
        self.validation_smooth = \
             gaussian_filter1d(self.validation, self.g_filt)\
                 .reshape(-1,1)

        #create time series generators
        self.generator = \
             TimeseriesGenerator(data=self.train_smooth,\
                                 targets=self.train_smooth,\
                                 length=self.length,\
                                 batch_size=self.batch_size)
                 
        self.val_generator = \
             TimeseriesGenerator(data=self.validation_smooth,\
                                 targets=self.validation_smooth,\
                                 length=self.length,\
                                 batch_size=self.batch_size)                 

    def fitModel(self):
        """
        Fits the model on your generators for training and validation sets.
        EarlyStopping call back ends training if val_loss doesnt improve.
        Record epoch metrics in a DataFrame.
        """
        self.model.fit(self.generator, validation_data=self.val_generator,\
                       epochs=self.epochs, callbacks=self.callbacks)
            
        self.history = pd.DataFrame(self.model.history.history)
        
    def loadModel(self):
        """
        Load a model instead of fitting a new one (uses model_name)
        """
        self.model = tf.keras.models.load_model(self.model_name)
            
    def predAhead(self, days, series=None):
        """
        Predicts a number of days ahead set by the user. Input your own
        series or dont if you want to predict off of the validation set.
        """
        assert self.num_step_preds == 1,\
            "sorry, function not yet available for multi step models"
        
        #use end of the validation set to project forward if no series given
        if series is None:
            series = self.validation
        
        #get end of the series to plug into the model
        assert len(series) >= self.length,\
            "series must be at least {} days".format(self.length)
            
        series_cut = series.iloc[-self.length:].values.reshape(-1,1)
            
        #predict ahead by appending predictions and removing first values
        pred_series = series_cut.reshape(1, self.length, self.n_features)

        predictions = []
        
        for i in range(days):
            pred = self.model.predict(pred_series)
            pred_series = np.append(pred_series[:,1:,:], [pred], axis=1)
            predictions.append(pred)
                    
        #convert to pandas series
        predictions = np.array(predictions)
        predictions = pd.Series(predictions.reshape(days))
        predictions.index = self.validation.index[-days:] +\
                                 dt.timedelta(days=days)
            
        return predictions
    
    def plotPreds(self, predictions, test_series=None, run_up=None,\
                  ylabel='units'):
        """
        plot the predictions of the model. plot them against another series
        (test series). plot with with a run up leading to the pred period
        (validation set).
        """
        #set up figure
        plt.figure(figsize=(10,6))
        plt.ylabel(ylabel)
        plt.xlabel('datetime')
        
        #plot lines
        if run_up is None:
            run_up = self.validation[-7:]
            
        if test_series is not None:
            plt.plot(pd.concat([run_up, test_series[:1]]))
            plt.plot(test_series)
            
        else:
            plt.plot(run_up)
            
        #plot points
        plt.scatter(predictions.index, predictions, edgecolors='k',\
                    label='predictions', c='#2ca02c', s=64)
            
        if test_series is not None:
            plt.scatter(test_series.index, test_series, marker='X',\
                        edgecolors='k', label='test_data', c='#ff7f0e', s=200)
                
        plt.legend()

# %%
def fastSearch(data: pd.Series, length: list, layers_num: list,\
               layers_type: list, units: list, g_filt: list, model_name: str,\
               best_dict=None):
    """
    First it will set all hyperparameters to their first value in the lists we
    pass in.
    Then list by list it will train the model, keeping the best performing
    element in that list.
    Its recommended that you pass in the resulting dictionary into this 
    function a second time.
    """
    #record time for file_name
    time_now = str(round(time.time()))
    
    #set initial values if no specified parameters given.
    if best_dict is None:
        best_dict = {}
        
        best_dict['length'] = [length[0], length]
        best_dict['layers_num'] = [layers_num[0], layers_num]
        best_dict['layers_type'] = [layers_type[0], layers_type]
        best_dict['units'] = [units[0], units]
        best_dict['g_filt'] = [g_filt[0], g_filt]
    
    records = pd.DataFrame()
    
    #go through each hyperparameter
    for key in best_dict.keys():
        if len(best_dict[key][1]) == 0:
            continue
        
        scores = []
        
        #go through each value
        for item in best_dict[key][1]:
            best_dict[key][0] = item
            
            model = \
                BuildModel(model_name=model_name,\
                           length=best_dict['length'][0],\
                           layers_num=best_dict['layers_num'][0], \
                           layers_type=best_dict['layers_type'][0],\
                           units=best_dict['units'][0],\
                           g_filt=best_dict['g_filt'][0], num_step_preds=1,\
                           epochs=120, batch_size=10, patience=15)
                    
            #setup data and train the model
            model.setupData(data)
            model.fitModel()
                         
            #calculate val_mae in unsmoothed original units
            best_model = tf.keras.models.load_model(model_name)
            preds = best_model.predict(model.val_generator)
            preds = pd.Series(preds[:,0],\
                        index = model.validation[model.length:].index)
        
            val_mae_og = (preds - model.validation[model.length:]).abs()\
                         .mean()
            
            record = pd.DataFrame(best_dict).iloc[:1] 
            record['val_mae_og'] = val_mae_og
            
            #append score
            scores.append(val_mae_og)
            records = records.append(record)
            records.to_csv('records_' + time_now + '.csv', index=False)
            
        #get param value that performed the best
        best_score = min(scores)
        best_dict[key][0] = best_dict[key][1][scores.index(best_score)]
        
    return records, best_dict

# %% [markdown]
# ##Use functions and class to optimise a model

# %%
length = [15, 30, 60]
layers_num = [1, 2]
layers_type = ['LSTM']
units = [20, 40, 80] 
g_filt = [0.5, 0.75, 1.0, 1.25]

model_name = 'precip_model.h5'

records, best_dict = fastSearch(precip_train, length, layers_num, layers_type, units, g_filt, model_name=model_name, best_dict=None)
records2, best_dict2 = fastSearch(precip_train, length, layers_num, layers_type, units, g_filt, model_name=model_name, best_dict=best_dict)

records_all = pd.concat([records,records2])
# Out:
# Epoch 1/120
# 193/193 [==============================] - 2s 6ms/step - loss: 12.2488 - mae: 2.1028 - val_loss: 18.4450 - val_mae: 2.3370
# Epoch 2/120
# 193/193 [==============================] - 1s 4ms/step - loss: 10.3698 - mae: 2.0440 - val_loss: 16.9310 - val_mae: 2.1889
# Epoch 3/120
# 193/193 [==============================] - 1s 4ms/step - loss: 9.8026 - mae: 2.0032 - val_loss: 15.8028 - val_mae: 2.1751
# Epoch 4/120
# 193/193 [==============================] - 1s 4ms/step - loss: 9.4286 - mae: 1.9555 - val_loss: 15.0805 - val_mae: 2.1273
# Epoch 5/120
# 193/193 [==============================] - 1s 4ms/step - loss: 9.1995 - mae: 1.9237 - val_loss: 14.6913 - val_mae: 2.0138
# Epoch 6/120
# 193/193 [==============================] - 1s 4ms/step - loss: 9.0670 - mae: 1.8902 - val_loss: 14.4162 - val_mae: 2.0526
# Epoch 7/120
# 193/193 [==============================] - 1s 4ms/step - loss: 8.9690 - mae: 1.8937 - val_loss: 14.2506 - val_mae: 2.0251
# Epoch 8/120
# 193/193 [==============================] - 1s 4ms/step - loss: 8.8834 - mae: 1.8658 - val_loss: 14.2212 - val_mae: 1.9801
# Epoch 9/120
# 193/193 [==============================] - 1s 4ms/step - loss: 8.8190 - mae: 1.8455 - val_loss: 14.1097 - val_mae: 2.0253
# Epoch 10/120
# 193/193 [==============================] - 1s 4ms/step - loss: 8.7735 - mae: 1.8380 - val_loss: 14.0513 - val_mae: 2.0236
# Epoch 11/120
# 193/193 [==============================] - 1s 4ms/step - loss: 8.7348 - mae: 1.8389 - val_loss: 13.9116 - val_mae: 1.9368
# Epoch 12/120
# 193/193 [==============================] - 1s 4ms/step - loss: 8.6835 - mae: 1.8208 - val_loss: 13.8810 - val_mae: 1.9211
# Epoch 13/120
# 193/193 [==============================] - 1s 4ms/step - loss: 8.6194 - mae: 1.8112 - val_loss: 13.8460 - val_mae: 1.8596
# Epoch 14/120
# 193/193 [==============================] - 1s 4ms/step - loss: 8.5951 - mae: 1.7948 - val_loss: 13.7202 - val_mae: 1.9255
# Epoch 15/120
# 193/193 [==============================] - 1s 4ms/step - loss: 8.5489 - mae: 1.7987 - val_loss: 13.7961 - val_mae: 1.8288
# Epoch 16/120
# 193/193 [==============================] - 1s 4ms/step - loss: 8.5303 - mae: 1.7819 - val_loss: 13.6667 - val_mae: 1.8479
# Epoch 17/120
# 193/193 [==============================] - 1s 4ms/step - loss: 8.5092 - mae: 1.7668 - val_loss: 13.6666 - val_mae: 1.9384
# Epoch 18/120
# 193/193 [==============================] - 1s 4ms/step - loss: 8.4961 - mae: 1.7882 - val_loss: 13.6322 - val_mae: 1.8538
# Epoch 19/120
# 193/193 [==============================] - 1s 4ms/step - loss: 8.4684 - mae: 1.7699 - val_loss: 13.5895 - val_mae: 1.8743
# Epoch 20/120
# 193/193 [==============================] - 1s 4ms/step - loss: 8.4329 - mae: 1.7692 - val_loss: 13.7214 - val_mae: 1.8196
# Epoch 21/120
# 193/193 [==============================] - 1s 4ms/step - loss: 8.4079 - mae: 1.7643 - val_loss: 13.6853 - val_mae: 1.8345
# Epoch 22/120
# 193/193 [==============================] - 1s 4ms/step - loss: 8.4028 - mae: 1.7626 - val_loss: 13.6682 - val_mae: 1.8238
# Epoch 23/120
# 193/193 [==============================] - 1s 4ms/step - loss: 8.4000 - mae: 1.7475 - val_loss: 13.6130 - val_mae: 1.8426
# Epoch 24/120
# 193/193 [==============================] - 1s 4ms/step - loss: 8.3547 - mae: 1.7524 - val_loss: 13.5542 - val_mae: 1.8538
# Epoch 25/120
# 193/193 [==============================] - 1s 4ms/step - loss: 8.3599 - mae: 1.7489 - val_loss: 13.6399 - val_mae: 1.8409
# Epoch 26/120
# 193/193 [==============================] - 1s 4ms/step - loss: 8.3375 - mae: 1.7552 - val_loss: 13.6141 - val_mae: 1.8232
# Epoch 27/120
# 193/193 [==============================] - 1s 4ms/step - loss: 8.3355 - mae: 1.7454 - val_loss: 13.5538 - val_mae: 1.8265
# Epoch 28/120
# 193/193 [==============================] - 1s 4ms/step - loss: 8.3063 - mae: 1.7395 - val_loss: 13.4950 - val_mae: 1.8527
# Epoch 29/120
# 193/193 [==============================] - 1s 4ms/step - loss: 8.3089 - mae: 1.7466 - val_loss: 13.5805 - val_mae: 1.8289
# Epoch 30/120
# 193/193 [==============================] - 1s 4ms/step - loss: 8.2808 - mae: 1.7332 - val_loss: 13.6835 - val_mae: 1.8591
# Epoch 31/120
# 193/193 [==============================] - 1s 4ms/step - loss: 8.2627 - mae: 1.7532 - val_loss: 13.4740 - val_mae: 1.8292
# Epoch 32/120
# 193/193 [==============================] - 1s 4ms/step - loss: 8.2565 - mae: 1.7379 - val_loss: 13.4186 - val_mae: 1.8226
# Epoch 33/120
# 193/193 [==============================] - 1s 4ms/step - loss: 8.2253 - mae: 1.7288 - val_loss: 13.3546 - val_mae: 1.8433
# Epoch 34/120
# 193/193 [==============================] - 1s 4ms/step - loss: 8.1990 - mae: 1.7448 - val_loss: 13.4680 - val_mae: 1.8122
# Epoch 35/120
# 193/193 [==============================] - 1s 4ms/step - loss: 8.2090 - mae: 1.7264 - val_loss: 13.3431 - val_mae: 1.8243
# Epoch 36/120
# 193/193 [==============================] - 1s 4ms/step - loss: 8.1744 - mae: 1.7328 - val_loss: 13.3579 - val_mae: 1.8040
# Epoch 37/120
# 193/193 [==============================] - 1s 4ms/step - loss: 8.1685 - mae: 1.7178 - val_loss: 13.2890 - val_mae: 1.8303
# Epoch 38/120
# 193/193 [==============================] - 1s 4ms/step - loss: 8.1338 - mae: 1.7204 - val_loss: 13.2853 - val_mae: 1.8242
# Epoch 39/120
# 193/193 [==============================] - 1s 4ms/step - loss: 8.1343 - mae: 1.7238 - val_loss: 13.2830 - val_mae: 1.8168
# Epoch 40/120
# 193/193 [==============================] - 1s 4ms/step - loss: 8.0881 - mae: 1.7109 - val_loss: 13.1507 - val_mae: 1.8539
# Epoch 41/120
# 193/193 [==============================] - 1s 4ms/step - loss: 8.0838 - mae: 1.7300 - val_loss: 13.2827 - val_mae: 1.7973
# Epoch 42/120
# 193/193 [==============================] - 1s 4ms/step - loss: 8.0829 - mae: 1.7163 - val_loss: 13.1776 - val_mae: 1.8259
# Epoch 43/120
# 193/193 [==============================] - 1s 4ms/step - loss: 8.0591 - mae: 1.7163 - val_loss: 13.1340 - val_mae: 1.8271
# Epoch 44/120
# 193/193 [==============================] - 1s 4ms/step - loss: 8.0612 - mae: 1.7211 - val_loss: 13.1791 - val_mae: 1.8063
# Epoch 45/120
# 193/193 [==============================] - 1s 4ms/step - loss: 8.0206 - mae: 1.7028 - val_loss: 13.1808 - val_mae: 1.8290
# Epoch 46/120
# 193/193 [==============================] - 1s 4ms/step - loss: 8.0081 - mae: 1.7105 - val_loss: 13.0484 - val_mae: 1.8494
# Epoch 47/120
# 193/193 [==============================] - 1s 4ms/step - loss: 7.9715 - mae: 1.7209 - val_loss: 13.2502 - val_mae: 1.8246
# Epoch 48/120
# 193/193 [==============================] - 1s 4ms/step - loss: 7.9639 - mae: 1.6965 - val_loss: 13.1364 - val_mae: 1.8319
# Epoch 49/120
# 193/193 [==============================] - 1s 4ms/step - loss: 7.9419 - mae: 1.7023 - val_loss: 13.0530 - val_mae: 1.8609
# Epoch 50/120
# 193/193 [==============================] - 1s 4ms/step - loss: 7.9321 - mae: 1.7087 - val_loss: 13.0918 - val_mae: 1.8448
# Epoch 51/120
# 193/193 [==============================] - 1s 4ms/step - loss: 7.9051 - mae: 1.7113 - val_loss: 13.0931 - val_mae: 1.8291
# Epoch 52/120
# 193/193 [==============================] - 1s 4ms/step - loss: 7.9034 - mae: 1.6993 - val_loss: 13.0402 - val_mae: 1.8443
# Epoch 53/120
# 193/193 [==============================] - 1s 4ms/step - loss: 7.8781 - mae: 1.7002 - val_loss: 13.1112 - val_mae: 1.8416
# Epoch 54/120
# 193/193 [==============================] - 1s 4ms/step - loss: 7.8620 - mae: 1.6991 - val_loss: 13.0603 - val_mae: 1.8543
# Epoch 55/120
# 193/193 [==============================] - 1s 4ms/step - loss: 7.8468 - mae: 1.6959 - val_loss: 13.0462 - val_mae: 1.8619
# Epoch 56/120
# 193/193 [==============================] - 1s 4ms/step - loss: 7.8324 - mae: 1.7109 - val_loss: 13.2060 - val_mae: 1.8380
# Epoch 57/120
# 193/193 [==============================] - 1s 4ms/step - loss: 7.7856 - mae: 1.6907 - val_loss: 13.2475 - val_mae: 1.8747
# Epoch 58/120
# 193/193 [==============================] - 1s 4ms/step - loss: 7.7915 - mae: 1.6943 - val_loss: 13.1152 - val_mae: 1.8361
# Epoch 59/120
# 193/193 [==============================] - 1s 4ms/step - loss: 7.7862 - mae: 1.6920 - val_loss: 13.0998 - val_mae: 1.8548
# Epoch 60/120
# 193/193 [==============================] - 1s 4ms/step - loss: 7.7788 - mae: 1.7028 - val_loss: 13.0828 - val_mae: 1.8457
# Epoch 61/120
# 193/193 [==============================] - 1s 4ms/step - loss: 7.7518 - mae: 1.6935 - val_loss: 13.0355 - val_mae: 1.8469
# Epoch 62/120
# 193/193 [==============================] - 1s 4ms/step - loss: 7.7330 - mae: 1.6907 - val_loss: 13.0580 - val_mae: 1.8683
# Epoch 63/120
# 193/193 [==============================] - 1s 4ms/step - loss: 7.7251 - mae: 1.6890 - val_loss: 13.0900 - val_mae: 1.8609
# Epoch 64/120
# 193/193 [==============================] - 1s 4ms/step - loss: 7.7007 - mae: 1.6953 - val_loss: 13.1446 - val_mae: 1.8427
# Epoch 65/120
# 193/193 [==============================] - 1s 4ms/step - loss: 7.6865 - mae: 1.6764 - val_loss: 13.0474 - val_mae: 1.8624
# Epoch 66/120
# 193/193 [==============================] - 1s 4ms/step - loss: 7.6688 - mae: 1.6932 - val_loss: 13.0331 - val_mae: 1.8547
# Epoch 67/120
# 193/193 [==============================] - 1s 4ms/step - loss: 7.6412 - mae: 1.6908 - val_loss: 13.1801 - val_mae: 1.8578
# Epoch 68/120
# 193/193 [==============================] - 1s 4ms/step - loss: 7.6716 - mae: 1.6846 - val_loss: 13.1344 - val_mae: 1.8660
# Epoch 69/120
# 193/193 [==============================] - 1s 4ms/step - loss: 7.6206 - mae: 1.6830 - val_loss: 13.1915 - val_mae: 1.8611
# Epoch 70/120
# 193/193 [==============================] - 1s 4ms/step - loss: 7.5867 - mae: 1.6849 - val_loss: 13.0603 - val_mae: 1.8452
# Epoch 71/120
# 193/193 [==============================] - 1s 4ms/step - loss: 7.5605 - mae: 1.6859 - val_loss: 13.2500 - val_mae: 1.8589
# Epoch 72/120
# 193/193 [==============================] - 1s 4ms/step - loss: 7.5730 - mae: 1.6710 - val_loss: 13.0924 - val_mae: 1.8726
# Epoch 73/120
# 193/193 [==============================] - 1s 4ms/step - loss: 7.5335 - mae: 1.6783 - val_loss: 13.1252 - val_mae: 1.8758
# Epoch 74/120
# 193/193 [==============================] - 1s 4ms/step - loss: 7.5238 - mae: 1.6809 - val_loss: 13.1451 - val_mae: 1.8580
# Epoch 75/120
# 193/193 [==============================] - 1s 4ms/step - loss: 7.5113 - mae: 1.6855 - val_loss: 13.1571 - val_mae: 1.8679
# Epoch 76/120
# 193/193 [==============================] - 1s 4ms/step - loss: 7.4809 - mae: 1.6767 - val_loss: 13.2175 - val_mae: 1.8646
# Epoch 77/120
# 193/193 [==============================] - 1s 4ms/step - loss: 7.4885 - mae: 1.6695 - val_loss: 13.0831 - val_mae: 1.8668
# Epoch 78/120
# 193/193 [==============================] - 1s 4ms/step - loss: 7.5054 - mae: 1.6747 - val_loss: 13.2885 - val_mae: 1.9147
# Epoch 79/120
# 193/193 [==============================] - 1s 4ms/step - loss: 7.4465 - mae: 1.6675 - val_loss: 13.1740 - val_mae: 1.9123
# Epoch 80/120
# 193/193 [==============================] - 1s 4ms/step - loss: 7.4490 - mae: 1.6730 - val_loss: 13.0859 - val_mae: 1.8750
# Epoch 81/120
# 193/193 [==============================] - 1s 4ms/step - loss: 7.4377 - mae: 1.6674 - val_loss: 13.2042 - val_mae: 1.8950
# Epoch 1/120
# 192/192 [==============================] - 2s 6ms/step - loss: 11.5583 - mae: 2.0981 - val_loss: 18.0517 - val_mae: 2.1109
# Epoch 2/120
# 192/192 [==============================] - 1s 5ms/step - loss: 9.9534 - mae: 1.9861 - val_loss: 16.1297 - val_mae: 2.1792
# Epoch 3/120
# 192/192 [==============================] - 1s 5ms/step - loss: 9.3850 - mae: 1.9529 - val_loss: 15.2248 - val_mae: 2.0398
# Epoch 4/120
# 192/192 [==============================] - 1s 5ms/step - loss: 9.1381 - mae: 1.9265 - val_loss: 14.7502 - val_mae: 1.9880
# Epoch 5/120
# 192/192 [==============================] - 1s 5ms/step - loss: 9.0221 - mae: 1.8732 - val_loss: 14.4816 - val_mae: 2.0284
# Epoch 6/120
# 192/192 [==============================] - 1s 5ms/step - loss: 8.9163 - mae: 1.8927 - val_loss: 14.4550 - val_mae: 1.9578
# Epoch 7/120
# 192/192 [==============================] - 1s 5ms/step - loss: 8.8557 - mae: 1.8520 - val_loss: 14.2837 - val_mae: 1.9845
# Epoch 8/120
# 192/192 [==============================] - 1s 5ms/step - loss: 8.7720 - mae: 1.8601 - val_loss: 14.2184 - val_mae: 1.9849
# Epoch 9/120
# 192/192 [==============================] - 1s 5ms/step - loss: 8.7071 - mae: 1.8451 - val_loss: 14.1709 - val_mae: 1.8901
# Epoch 10/120
# 192/192 [==============================] - 1s 5ms/step - loss: 8.6583 - mae: 1.8095 - val_loss: 14.0348 - val_mae: 1.9131
# Epoch 11/120
# 192/192 [==============================] - 1s 5ms/step - loss: 8.6050 - mae: 1.8163 - val_loss: 14.1116 - val_mae: 1.8841
# Epoch 12/120
# 192/192 [==============================] - 1s 5ms/step - loss: 8.5735 - mae: 1.7815 - val_loss: 13.8146 - val_mae: 1.9266
# Epoch 13/120
# 192/192 [==============================] - 1s 4ms/step - loss: 8.5639 - mae: 1.8081 - val_loss: 13.7980 - val_mae: 1.8492
# Epoch 14/120
# 192/192 [==============================] - 1s 5ms/step - loss: 8.5199 - mae: 1.7787 - val_loss: 13.7915 - val_mae: 1.8712
# Epoch 15/120
# 192/192 [==============================] - 1s 4ms/step - loss: 8.4970 - mae: 1.7920 - val_loss: 13.8765 - val_mae: 1.8277
# Epoch 16/120
# 192/192 [==============================] - 1s 5ms/step - loss: 8.4643 - mae: 1.7646 - val_loss: 13.7009 - val_mae: 1.8444
# Epoch 17/120
# 192/192 [==============================] - 1s 5ms/step - loss: 8.4553 - mae: 1.7640 - val_loss: 13.7258 - val_mae: 1.8302
# Epoch 18/120
# 192/192 [==============================] - 1s 5ms/step - loss: 8.4110 - mae: 1.7501 - val_loss: 13.6164 - val_mae: 1.8920
# Epoch 19/120
# 192/192 [==============================] - 1s 5ms/step - loss: 8.3909 - mae: 1.7677 - val_loss: 13.7120 - val_mae: 1.8049
# Epoch 20/120
# 192/192 [==============================] - 1s 5ms/step - loss: 8.3686 - mae: 1.7550 - val_loss: 13.7215 - val_mae: 1.7818
# Epoch 21/120
# 192/192 [==============================] - 1s 5ms/step - loss: 8.3586 - mae: 1.7343 - val_loss: 13.6471 - val_mae: 1.8031
# Epoch 22/120
# 192/192 [==============================] - 1s 5ms/step - loss: 8.3373 - mae: 1.7460 - val_loss: 13.5944 - val_mae: 1.8301
# Epoch 23/120
# 192/192 [==============================] - 1s 5ms/step - loss: 8.3259 - mae: 1.7422 - val_loss: 13.5729 - val_mae: 1.7790
# Epoch 24/120
# 192/192 [==============================] - 1s 5ms/step - loss: 8.3301 - mae: 1.7341 - val_loss: 13.5519 - val_mae: 1.8017
# Epoch 25/120
# 192/192 [==============================] - 1s 5ms/step - loss: 8.2906 - mae: 1.7362 - val_loss: 13.6198 - val_mae: 1.8021
# Epoch 26/120
# 192/192 [==============================] - 1s 5ms/step - loss: 8.2631 - mae: 1.7246 - val_loss: 13.5198 - val_mae: 1.8305
# Epoch 27/120
# 192/192 [==============================] - 1s 5ms/step - loss: 8.2622 - mae: 1.7341 - val_loss: 13.4328 - val_mae: 1.8119
# Epoch 28/120
# 192/192 [==============================] - 1s 5ms/step - loss: 8.2139 - mae: 1.7317 - val_loss: 13.5935 - val_mae: 1.8017
# Epoch 29/120
# 192/192 [==============================] - 1s 5ms/step - loss: 8.1844 - mae: 1.7120 - val_loss: 13.3881 - val_mae: 1.8422
# Epoch 30/120
# 192/192 [==============================] - 1s 5ms/step - loss: 8.1825 - mae: 1.7316 - val_loss: 13.5887 - val_mae: 1.8149
# Epoch 31/120
# 192/192 [==============================] - 1s 5ms/step - loss: 8.2201 - mae: 1.7317 - val_loss: 13.5616 - val_mae: 1.8033
# Epoch 32/120
# 192/192 [==============================] - 1s 5ms/step - loss: 8.1469 - mae: 1.7109 - val_loss: 13.5006 - val_mae: 1.8238
# Epoch 33/120
# 192/192 [==============================] - 1s 5ms/step - loss: 8.1059 - mae: 1.7268 - val_loss: 13.6830 - val_mae: 1.7717
# Epoch 34/120
# 192/192 [==============================] - 1s 5ms/step - loss: 8.1112 - mae: 1.6994 - val_loss: 13.3119 - val_mae: 1.8348
# Epoch 35/120
# 192/192 [==============================] - 1s 5ms/step - loss: 8.1214 - mae: 1.7254 - val_loss: 13.5575 - val_mae: 1.8167
# Epoch 36/120
# 192/192 [==============================] - 1s 5ms/step - loss: 8.0823 - mae: 1.7092 - val_loss: 13.5720 - val_mae: 1.8390
# Epoch 37/120
# 192/192 [==============================] - 1s 4ms/step - loss: 8.0859 - mae: 1.7185 - val_loss: 13.5847 - val_mae: 1.8287
# Epoch 38/120
# 192/192 [==============================] - 1s 5ms/step - loss: 8.0614 - mae: 1.7124 - val_loss: 13.5913 - val_mae: 1.8191
# Epoch 39/120
# 192/192 [==============================] - 1s 5ms/step - loss: 8.0361 - mae: 1.7185 - val_loss: 13.6749 - val_mae: 1.7979
# Epoch 40/120
# 192/192 [==============================] - 1s 5ms/step - loss: 8.0265 - mae: 1.6973 - val_loss: 13.5773 - val_mae: 1.8278
# Epoch 41/120
# 192/192 [==============================] - 1s 5ms/step - loss: 8.0178 - mae: 1.7125 - val_loss: 13.4740 - val_mae: 1.8274
# Epoch 42/120
# 192/192 [==============================] - 1s 5ms/step - loss: 8.0111 - mae: 1.7115 - val_loss: 13.5424 - val_mae: 1.8474
# Epoch 43/120
# 192/192 [==============================] - 1s 5ms/step - loss: 8.0147 - mae: 1.7080 - val_loss: 13.2660 - val_mae: 1.8111
# Epoch 44/120
# 192/192 [==============================] - 1s 5ms/step - loss: 7.9831 - mae: 1.7106 - val_loss: 13.4241 - val_mae: 1.7907
# Epoch 45/120
# 192/192 [==============================] - 1s 4ms/step - loss: 7.9524 - mae: 1.6869 - val_loss: 13.5266 - val_mae: 1.8698
# Epoch 46/120
# 192/192 [==============================] - 1s 5ms/step - loss: 7.9393 - mae: 1.7163 - val_loss: 13.5864 - val_mae: 1.8084
# Epoch 47/120
# 192/192 [==============================] - 1s 5ms/step - loss: 7.9301 - mae: 1.6881 - val_loss: 13.5555 - val_mae: 1.8544
# Epoch 48/120
# 192/192 [==============================] - 1s 5ms/step - loss: 7.9368 - mae: 1.7121 - val_loss: 13.6350 - val_mae: 1.8225
# Epoch 49/120
# 192/192 [==============================] - 1s 5ms/step - loss: 7.9209 - mae: 1.6912 - val_loss: 13.5631 - val_mae: 1.8390
# Epoch 50/120
# 192/192 [==============================] - 1s 5ms/step - loss: 7.8906 - mae: 1.6965 - val_loss: 13.5305 - val_mae: 1.8280
# Epoch 51/120
# 192/192 [==============================] - 1s 5ms/step - loss: 7.9488 - mae: 1.6966 - val_loss: 13.5469 - val_mae: 1.8406
# Epoch 52/120
# 192/192 [==============================] - 1s 5ms/step - loss: 7.8694 - mae: 1.7010 - val_loss: 13.6102 - val_mae: 1.8023
# Epoch 53/120
# 192/192 [==============================] - 1s 5ms/step - loss: 7.8547 - mae: 1.6920 - val_loss: 13.6627 - val_mae: 1.8232
# Epoch 54/120
# 192/192 [==============================] - 1s 5ms/step - loss: 7.8618 - mae: 1.7020 - val_loss: 13.3314 - val_mae: 1.7915
# Epoch 55/120
# 192/192 [==============================] - 1s 5ms/step - loss: 7.9857 - mae: 1.7086 - val_loss: 13.5596 - val_mae: 1.8436
# Epoch 56/120
# 192/192 [==============================] - 1s 5ms/step - loss: 7.9498 - mae: 1.6973 - val_loss: 13.5270 - val_mae: 1.8106
# Epoch 57/120
# 192/192 [==============================] - 1s 5ms/step - loss: 7.8273 - mae: 1.6829 - val_loss: 13.4070 - val_mae: 1.8742
# Epoch 58/120
# 192/192 [==============================] - 1s 5ms/step - loss: 7.8246 - mae: 1.6984 - val_loss: 13.4477 - val_mae: 1.8180
# Epoch 1/120
# 189/189 [==============================] - 3s 7ms/step - loss: 12.6382 - mae: 2.1442 - val_loss: 20.7972 - val_mae: 2.4820
# Epoch 2/120
# 189/189 [==============================] - 1s 5ms/step - loss: 10.6075 - mae: 2.0514 - val_loss: 18.7546 - val_mae: 2.2672
# Epoch 3/120
# 189/189 [==============================] - 1s 5ms/step - loss: 9.8024 - mae: 1.9742 - val_loss: 17.5727 - val_mae: 2.1076
# Epoch 4/120
# 189/189 [==============================] - 1s 5ms/step - loss: 9.4187 - mae: 1.8920 - val_loss: 16.7789 - val_mae: 2.2339
# Epoch 5/120
# 189/189 [==============================] - 1s 5ms/step - loss: 9.1625 - mae: 1.9035 - val_loss: 16.2900 - val_mae: 2.1177
# Epoch 6/120
# 189/189 [==============================] - 1s 5ms/step - loss: 8.9867 - mae: 1.8807 - val_loss: 15.9337 - val_mae: 2.0936
# Epoch 7/120
# 189/189 [==============================] - 1s 5ms/step - loss: 8.8732 - mae: 1.8553 - val_loss: 15.7444 - val_mae: 2.0776
# Epoch 8/120
# 189/189 [==============================] - 1s 6ms/step - loss: 8.7963 - mae: 1.8498 - val_loss: 15.5884 - val_mae: 2.0233
# Epoch 9/120
# 189/189 [==============================] - 1s 6ms/step - loss: 8.7385 - mae: 1.8231 - val_loss: 15.4404 - val_mae: 2.0114
# Epoch 10/120
# 189/189 [==============================] - 1s 5ms/step - loss: 8.6890 - mae: 1.8330 - val_loss: 15.3012 - val_mae: 1.9858
# Epoch 11/120
# 189/189 [==============================] - 1s 5ms/step - loss: 8.6595 - mae: 1.8065 - val_loss: 15.2670 - val_mae: 1.9793
# Epoch 12/120
# 189/189 [==============================] - 1s 5ms/step - loss: 8.6309 - mae: 1.8287 - val_loss: 15.2493 - val_mae: 1.9230
# Epoch 13/120
# 189/189 [==============================] - 1s 5ms/step - loss: 8.5876 - mae: 1.7954 - val_loss: 15.1536 - val_mae: 1.9616
# Epoch 14/120
# 189/189 [==============================] - 1s 5ms/step - loss: 8.5784 - mae: 1.7984 - val_loss: 15.2115 - val_mae: 1.9582
# Epoch 15/120
# 189/189 [==============================] - 1s 5ms/step - loss: 8.5516 - mae: 1.7897 - val_loss: 15.1078 - val_mae: 1.9228
# Epoch 16/120
# 189/189 [==============================] - 1s 5ms/step - loss: 8.5201 - mae: 1.7789 - val_loss: 15.0155 - val_mae: 1.9782
# Epoch 17/120
# 189/189 [==============================] - 1s 5ms/step - loss: 8.5048 - mae: 1.7805 - val_loss: 14.9758 - val_mae: 1.9675
# Epoch 18/120
# 189/189 [==============================] - 1s 5ms/step - loss: 8.4776 - mae: 1.7938 - val_loss: 15.0587 - val_mae: 1.8979
# Epoch 19/120
# 189/189 [==============================] - 1s 5ms/step - loss: 8.4688 - mae: 1.7616 - val_loss: 14.9427 - val_mae: 1.9470
# Epoch 20/120
# 189/189 [==============================] - 1s 5ms/step - loss: 8.4536 - mae: 1.7780 - val_loss: 14.9581 - val_mae: 1.9155
# Epoch 21/120
# 189/189 [==============================] - 1s 5ms/step - loss: 8.4343 - mae: 1.7597 - val_loss: 14.8981 - val_mae: 1.9045
# Epoch 22/120
# 189/189 [==============================] - 1s 5ms/step - loss: 8.4311 - mae: 1.7615 - val_loss: 14.8984 - val_mae: 1.9269
# Epoch 23/120
# 189/189 [==============================] - 1s 5ms/step - loss: 8.4150 - mae: 1.7540 - val_loss: 14.7503 - val_mae: 1.9444
# Epoch 24/120
# 189/189 [==============================] - 1s 5ms/step - loss: 8.3975 - mae: 1.7687 - val_loss: 14.7674 - val_mae: 1.9058
# Epoch 25/120
# 189/189 [==============================] - 1s 5ms/step - loss: 8.3591 - mae: 1.7422 - val_loss: 14.6208 - val_mae: 1.9704
# Epoch 26/120
# 189/189 [==============================] - 1s 5ms/step - loss: 8.3795 - mae: 1.7598 - val_loss: 14.6751 - val_mae: 1.9157
# Epoch 27/120
# 189/189 [==============================] - 1s 5ms/step - loss: 8.3670 - mae: 1.7587 - val_loss: 14.6935 - val_mae: 1.9182
# Epoch 28/120
# 189/189 [==============================] - 1s 5ms/step - loss: 8.3491 - mae: 1.7606 - val_loss: 14.7088 - val_mae: 1.8745
# Epoch 29/120
# 189/189 [==============================] - 1s 5ms/step - loss: 8.3275 - mae: 1.7332 - val_loss: 14.6394 - val_mae: 1.8839
# Epoch 30/120
# 189/189 [==============================] - 1s 5ms/step - loss: 8.3213 - mae: 1.7598 - val_loss: 14.6270 - val_mae: 1.8892
# Epoch 31/120
# 189/189 [==============================] - 1s 5ms/step - loss: 8.3194 - mae: 1.7437 - val_loss: 14.6064 - val_mae: 1.8840
# Epoch 32/120
# 189/189 [==============================] - 1s 5ms/step - loss: 8.3076 - mae: 1.7320 - val_loss: 14.6041 - val_mae: 1.9205
# Epoch 33/120
# 189/189 [==============================] - 1s 5ms/step - loss: 8.2965 - mae: 1.7493 - val_loss: 14.4903 - val_mae: 1.8877
# Epoch 34/120
# 189/189 [==============================] - 1s 5ms/step - loss: 8.2877 - mae: 1.7407 - val_loss: 14.5317 - val_mae: 1.8849
# Epoch 35/120
# 189/189 [==============================] - 1s 5ms/step - loss: 8.2778 - mae: 1.7399 - val_loss: 14.4921 - val_mae: 1.8720
# Epoch 36/120
# 189/189 [==============================] - 1s 6ms/step - loss: 8.2620 - mae: 1.7286 - val_loss: 14.4362 - val_mae: 1.8800
# Epoch 37/120
# 189/189 [==============================] - 1s 5ms/step - loss: 8.2633 - mae: 1.7305 - val_loss: 14.5203 - val_mae: 1.8778
# Epoch 38/120
# 189/189 [==============================] - 1s 5ms/step - loss: 8.2569 - mae: 1.7427 - val_loss: 14.4595 - val_mae: 1.9343
# Epoch 39/120
# 189/189 [==============================] - 1s 5ms/step - loss: 8.2428 - mae: 1.7394 - val_loss: 14.4623 - val_mae: 1.8653
# Epoch 40/120
# 189/189 [==============================] - 1s 5ms/step - loss: 8.2363 - mae: 1.7284 - val_loss: 14.6507 - val_mae: 1.9137
# Epoch 41/120
# 189/189 [==============================] - 1s 5ms/step - loss: 8.2274 - mae: 1.7264 - val_loss: 14.4146 - val_mae: 1.8771
# Epoch 42/120
# 189/189 [==============================] - 1s 6ms/step - loss: 8.2175 - mae: 1.7337 - val_loss: 14.4133 - val_mae: 1.8706
# Epoch 43/120
# 189/189 [==============================] - 1s 5ms/step - loss: 8.1861 - mae: 1.7165 - val_loss: 14.2430 - val_mae: 1.9198
# Epoch 44/120
# 189/189 [==============================] - 1s 5ms/step - loss: 8.1909 - mae: 1.7246 - val_loss: 14.2652 - val_mae: 1.9196
# Epoch 45/120
# 189/189 [==============================] - 1s 5ms/step - loss: 8.1768 - mae: 1.7405 - val_loss: 14.4824 - val_mae: 1.8844
# Epoch 46/120
# 189/189 [==============================] - 1s 5ms/step - loss: 8.1755 - mae: 1.7266 - val_loss: 14.4753 - val_mae: 1.8742
# Epoch 47/120
# 189/189 [==============================] - 1s 5ms/step - loss: 8.1465 - mae: 1.7224 - val_loss: 14.4572 - val_mae: 1.8750
# Epoch 48/120
# 189/189 [==============================] - 1s 5ms/step - loss: 8.1515 - mae: 1.7155 - val_loss: 14.3613 - val_mae: 1.8631
# Epoch 49/120
# 189/189 [==============================] - 1s 5ms/step - loss: 8.1269 - mae: 1.7186 - val_loss: 14.4278 - val_mae: 1.8695
# Epoch 50/120
# 189/189 [==============================] - 1s 5ms/step - loss: 8.1089 - mae: 1.7064 - val_loss: 14.3473 - val_mae: 1.8928
# Epoch 51/120
# 189/189 [==============================] - 1s 5ms/step - loss: 8.0999 - mae: 1.7130 - val_loss: 14.3052 - val_mae: 1.9025
# Epoch 52/120
# 189/189 [==============================] - 1s 5ms/step - loss: 8.1184 - mae: 1.7168 - val_loss: 14.3598 - val_mae: 1.8665
# Epoch 53/120
# 189/189 [==============================] - 1s 5ms/step - loss: 8.0738 - mae: 1.7081 - val_loss: 14.3431 - val_mae: 1.8871
# Epoch 54/120
# 189/189 [==============================] - 1s 5ms/step - loss: 8.0676 - mae: 1.7150 - val_loss: 14.3448 - val_mae: 1.8700
# Epoch 55/120
# 189/189 [==============================] - 1s 5ms/step - loss: 8.0477 - mae: 1.7061 - val_loss: 14.3481 - val_mae: 1.8585
# Epoch 56/120
# 189/189 [==============================] - 1s 5ms/step - loss: 8.1132 - mae: 1.7121 - val_loss: 14.1758 - val_mae: 1.8605
# Epoch 57/120
# 189/189 [==============================] - 1s 5ms/step - loss: 8.1140 - mae: 1.7125 - val_loss: 14.1465 - val_mae: 1.8862
# Epoch 58/120
# 189/189 [==============================] - 1s 5ms/step - loss: 8.0990 - mae: 1.7105 - val_loss: 14.1414 - val_mae: 1.8676
# Epoch 59/120
# 189/189 [==============================] - 1s 5ms/step - loss: 8.0797 - mae: 1.7119 - val_loss: 14.1541 - val_mae: 1.8713
# Epoch 60/120
# 189/189 [==============================] - 1s 5ms/step - loss: 8.0709 - mae: 1.7148 - val_loss: 14.2765 - val_mae: 1.8788
# Epoch 61/120
# 189/189 [==============================] - 1s 5ms/step - loss: 8.0267 - mae: 1.7023 - val_loss: 14.2722 - val_mae: 1.9159
# Epoch 62/120
# 189/189 [==============================] - 1s 5ms/step - loss: 8.0167 - mae: 1.7100 - val_loss: 14.2639 - val_mae: 1.8798
# Epoch 63/120
# 189/189 [==============================] - 1s 5ms/step - loss: 7.9900 - mae: 1.7067 - val_loss: 14.3313 - val_mae: 1.8791
# Epoch 64/120
# 189/189 [==============================] - 1s 5ms/step - loss: 7.9683 - mae: 1.6935 - val_loss: 14.2873 - val_mae: 1.8856
# Epoch 65/120
# 189/189 [==============================] - 1s 5ms/step - loss: 8.0309 - mae: 1.7072 - val_loss: 14.1291 - val_mae: 1.8604
# Epoch 66/120
# 189/189 [==============================] - 1s 5ms/step - loss: 8.0289 - mae: 1.7071 - val_loss: 14.2337 - val_mae: 1.8746
# Epoch 67/120
# 189/189 [==============================] - 1s 5ms/step - loss: 7.9789 - mae: 1.7032 - val_loss: 14.5002 - val_mae: 1.9144
# Epoch 68/120
# 189/189 [==============================] - 1s 6ms/step - loss: 7.9470 - mae: 1.6984 - val_loss: 14.2467 - val_mae: 1.8993
# Epoch 69/120
# 189/189 [==============================] - 1s 5ms/step - loss: 7.9414 - mae: 1.6937 - val_loss: 14.2527 - val_mae: 1.8948
# Epoch 70/120
# 189/189 [==============================] - 1s 5ms/step - loss: 7.9137 - mae: 1.7017 - val_loss: 14.1425 - val_mae: 1.8911
# Epoch 71/120
# 189/189 [==============================] - 1s 5ms/step - loss: 7.9103 - mae: 1.6974 - val_loss: 14.2152 - val_mae: 1.8581
# Epoch 72/120
# 189/189 [==============================] - 1s 5ms/step - loss: 7.9246 - mae: 1.6920 - val_loss: 14.2084 - val_mae: 1.8889
# Epoch 73/120
# 189/189 [==============================] - 1s 5ms/step - loss: 7.9087 - mae: 1.6970 - val_loss: 14.1594 - val_mae: 1.8725
# Epoch 74/120
# 189/189 [==============================] - 1s 5ms/step - loss: 7.8670 - mae: 1.6873 - val_loss: 14.0885 - val_mae: 1.8798
# Epoch 75/120
# 189/189 [==============================] - 1s 5ms/step - loss: 7.8799 - mae: 1.7077 - val_loss: 14.2006 - val_mae: 1.8770
# Epoch 76/120
# 189/189 [==============================] - 1s 5ms/step - loss: 7.8835 - mae: 1.6799 - val_loss: 14.1579 - val_mae: 1.8832
# Epoch 77/120
# 189/189 [==============================] - 1s 5ms/step - loss: 7.8615 - mae: 1.6975 - val_loss: 14.0447 - val_mae: 1.8880
# Epoch 78/120
# 189/189 [==============================] - 1s 5ms/step - loss: 7.8497 - mae: 1.6906 - val_loss: 14.2144 - val_mae: 1.8953
# Epoch 79/120
# 189/189 [==============================] - 1s 5ms/step - loss: 7.8245 - mae: 1.6900 - val_loss: 14.1370 - val_mae: 1.8918
# Epoch 80/120
# 189/189 [==============================] - 1s 5ms/step - loss: 7.8156 - mae: 1.6827 - val_loss: 14.0709 - val_mae: 1.8910
# Epoch 81/120
# 189/189 [==============================] - 1s 5ms/step - loss: 7.8003 - mae: 1.6861 - val_loss: 14.0734 - val_mae: 1.9011
# Epoch 82/120
# 189/189 [==============================] - 1s 5ms/step - loss: 7.8367 - mae: 1.7014 - val_loss: 13.9824 - val_mae: 1.8642
# Epoch 83/120
# 189/189 [==============================] - 1s 5ms/step - loss: 7.8644 - mae: 1.7026 - val_loss: 14.0777 - val_mae: 1.8869
# Epoch 84/120
# 189/189 [==============================] - 1s 5ms/step - loss: 7.7712 - mae: 1.6714 - val_loss: 14.1329 - val_mae: 1.9255
# Epoch 85/120
# 189/189 [==============================] - 1s 5ms/step - loss: 7.8790 - mae: 1.7179 - val_loss: 14.0486 - val_mae: 1.9035
# Epoch 86/120
# 189/189 [==============================] - 1s 5ms/step - loss: 7.7835 - mae: 1.6952 - val_loss: 14.0334 - val_mae: 1.9001
# Epoch 87/120
# 189/189 [==============================] - 1s 5ms/step - loss: 7.7197 - mae: 1.6794 - val_loss: 14.0368 - val_mae: 1.9022
# Epoch 88/120
# 189/189 [==============================] - 1s 5ms/step - loss: 7.7418 - mae: 1.6850 - val_loss: 13.9896 - val_mae: 1.8932
# Epoch 89/120
# 189/189 [==============================] - 1s 5ms/step - loss: 7.7235 - mae: 1.6876 - val_loss: 13.9876 - val_mae: 1.8885
# Epoch 90/120
# 189/189 [==============================] - 1s 6ms/step - loss: 7.6990 - mae: 1.6923 - val_loss: 14.0052 - val_mae: 1.8842
# Epoch 91/120
# 189/189 [==============================] - 1s 5ms/step - loss: 7.7751 - mae: 1.6899 - val_loss: 13.9679 - val_mae: 1.8907
# Epoch 92/120
# 189/189 [==============================] - 1s 5ms/step - loss: 7.6827 - mae: 1.6843 - val_loss: 13.9905 - val_mae: 1.9072
# Epoch 93/120
# 189/189 [==============================] - 1s 5ms/step - loss: 7.6760 - mae: 1.6877 - val_loss: 13.9397 - val_mae: 1.9091
# Epoch 94/120
# 189/189 [==============================] - 1s 6ms/step - loss: 7.6823 - mae: 1.6844 - val_loss: 13.9289 - val_mae: 1.8934
# Epoch 95/120
# 189/189 [==============================] - 1s 6ms/step - loss: 7.6062 - mae: 1.6815 - val_loss: 14.0181 - val_mae: 1.9251
# Epoch 96/120
# 189/189 [==============================] - 1s 6ms/step - loss: 7.7032 - mae: 1.7061 - val_loss: 13.9630 - val_mae: 1.8890
# Epoch 97/120
# 189/189 [==============================] - 1s 6ms/step - loss: 7.6195 - mae: 1.6744 - val_loss: 13.8883 - val_mae: 1.9057
# Epoch 98/120
# 189/189 [==============================] - 1s 6ms/step - loss: 7.6918 - mae: 1.6959 - val_loss: 13.9125 - val_mae: 1.8993
# Epoch 99/120
# 189/189 [==============================] - 1s 5ms/step - loss: 7.5902 - mae: 1.6788 - val_loss: 13.9115 - val_mae: 1.8878
# Epoch 100/120
# 189/189 [==============================] - 1s 6ms/step - loss: 7.6222 - mae: 1.6777 - val_loss: 14.3338 - val_mae: 1.9483
# Epoch 101/120
# 189/189 [==============================] - 1s 5ms/step - loss: 8.1942 - mae: 1.7390 - val_loss: 14.5455 - val_mae: 1.9554
# Epoch 102/120
# 189/189 [==============================] - 1s 6ms/step - loss: 7.9249 - mae: 1.7017 - val_loss: 14.3067 - val_mae: 1.9160
# Epoch 103/120
# 189/189 [==============================] - 1s 6ms/step - loss: 7.8305 - mae: 1.7013 - val_loss: 14.2275 - val_mae: 1.9004
# Epoch 104/120
# 189/189 [==============================] - 1s 6ms/step - loss: 7.7812 - mae: 1.6712 - val_loss: 13.9744 - val_mae: 1.9084
# Epoch 105/120
# 189/189 [==============================] - 1s 5ms/step - loss: 7.7397 - mae: 1.7004 - val_loss: 13.9997 - val_mae: 1.9157
# Epoch 106/120
# 189/189 [==============================] - 1s 5ms/step - loss: 7.6948 - mae: 1.6794 - val_loss: 14.0326 - val_mae: 1.9214
# Epoch 107/120
# 189/189 [==============================] - 1s 5ms/step - loss: 7.6403 - mae: 1.6814 - val_loss: 13.9648 - val_mae: 1.9276
# Epoch 108/120
# 189/189 [==============================] - 1s 5ms/step - loss: 7.6086 - mae: 1.6792 - val_loss: 13.9306 - val_mae: 1.9432
# Epoch 109/120
# 189/189 [==============================] - 1s 5ms/step - loss: 7.5765 - mae: 1.6840 - val_loss: 14.0341 - val_mae: 1.9269
# Epoch 110/120
# 189/189 [==============================] - 1s 5ms/step - loss: 7.5904 - mae: 1.6698 - val_loss: 14.1590 - val_mae: 1.9533
# Epoch 111/120
# 189/189 [==============================] - 1s 5ms/step - loss: 7.7462 - mae: 1.6908 - val_loss: 14.0018 - val_mae: 1.9730
# Epoch 112/120
# 189/189 [==============================] - 1s 5ms/step - loss: 7.4976 - mae: 1.6682 - val_loss: 13.9712 - val_mae: 1.9805
# Epoch 1/120
# 192/192 [==============================] - 3s 6ms/step - loss: 12.1760 - mae: 2.0393 - val_loss: 18.9483 - val_mae: 2.5232
# Epoch 2/120
# 192/192 [==============================] - 1s 5ms/step - loss: 10.2868 - mae: 2.0586 - val_loss: 16.7363 - val_mae: 2.2229
# Epoch 3/120
# 192/192 [==============================] - 1s 5ms/step - loss: 9.6485 - mae: 1.9672 - val_loss: 15.8078 - val_mae: 2.2143
# Epoch 4/120
# 192/192 [==============================] - 1s 5ms/step - loss: 9.2809 - mae: 1.9456 - val_loss: 15.1982 - val_mae: 2.0452
# Epoch 5/120
# 192/192 [==============================] - 1s 5ms/step - loss: 9.0484 - mae: 1.8846 - val_loss: 14.8295 - val_mae: 2.0879
# Epoch 6/120
# 192/192 [==============================] - 1s 5ms/step - loss: 8.9015 - mae: 1.8648 - val_loss: 14.5799 - val_mae: 2.0244
# Epoch 7/120
# 192/192 [==============================] - 1s 5ms/step - loss: 8.8155 - mae: 1.8695 - val_loss: 14.3564 - val_mae: 1.9161
# Epoch 8/120
# 192/192 [==============================] - 1s 5ms/step - loss: 8.7445 - mae: 1.8385 - val_loss: 14.2596 - val_mae: 1.8882
# Epoch 9/120
# 192/192 [==============================] - 1s 5ms/step - loss: 8.6895 - mae: 1.8190 - val_loss: 14.2109 - val_mae: 1.9044
# Epoch 10/120
# 192/192 [==============================] - 1s 5ms/step - loss: 8.6548 - mae: 1.8110 - val_loss: 14.0396 - val_mae: 1.9091
# Epoch 11/120
# 192/192 [==============================] - 1s 5ms/step - loss: 8.6002 - mae: 1.8181 - val_loss: 14.0424 - val_mae: 1.7974
# Epoch 12/120
# 192/192 [==============================] - 1s 5ms/step - loss: 8.5746 - mae: 1.7753 - val_loss: 13.8768 - val_mae: 1.8863
# Epoch 13/120
# 192/192 [==============================] - 1s 5ms/step - loss: 8.5626 - mae: 1.8073 - val_loss: 13.9462 - val_mae: 1.8215
# Epoch 14/120
# 192/192 [==============================] - 1s 5ms/step - loss: 8.5265 - mae: 1.7899 - val_loss: 13.9614 - val_mae: 1.8376
# Epoch 15/120
# 192/192 [==============================] - 1s 5ms/step - loss: 8.5140 - mae: 1.7613 - val_loss: 13.8933 - val_mae: 1.9039
# Epoch 16/120
# 192/192 [==============================] - 1s 5ms/step - loss: 8.4869 - mae: 1.7819 - val_loss: 13.7660 - val_mae: 1.8587
# Epoch 17/120
# 192/192 [==============================] - 1s 5ms/step - loss: 8.4859 - mae: 1.7792 - val_loss: 13.7450 - val_mae: 1.8425
# Epoch 18/120
# 192/192 [==============================] - 1s 5ms/step - loss: 8.4659 - mae: 1.7743 - val_loss: 13.7022 - val_mae: 1.8344
# Epoch 19/120
# 192/192 [==============================] - 1s 5ms/step - loss: 8.4585 - mae: 1.7637 - val_loss: 13.6835 - val_mae: 1.8349
# Epoch 20/120
# 192/192 [==============================] - 1s 5ms/step - loss: 8.4435 - mae: 1.7702 - val_loss: 13.7345 - val_mae: 1.8244
# Epoch 21/120
# 192/192 [==============================] - 1s 5ms/step - loss: 8.4233 - mae: 1.7599 - val_loss: 13.7442 - val_mae: 1.7928
# Epoch 22/120
# 192/192 [==============================] - 1s 5ms/step - loss: 8.4151 - mae: 1.7535 - val_loss: 13.5927 - val_mae: 1.8321
# Epoch 23/120
# 192/192 [==============================] - 1s 5ms/step - loss: 8.3996 - mae: 1.7515 - val_loss: 13.5680 - val_mae: 1.8522
# Epoch 24/120
# 192/192 [==============================] - 1s 5ms/step - loss: 8.4063 - mae: 1.7601 - val_loss: 13.6121 - val_mae: 1.8506
# Epoch 25/120
# 192/192 [==============================] - 1s 5ms/step - loss: 8.3768 - mae: 1.7624 - val_loss: 13.9548 - val_mae: 1.8122
# Epoch 26/120
# 192/192 [==============================] - 1s 5ms/step - loss: 8.3604 - mae: 1.7354 - val_loss: 13.7601 - val_mae: 1.8206
# Epoch 27/120
# 192/192 [==============================] - 1s 5ms/step - loss: 8.3561 - mae: 1.7670 - val_loss: 13.7995 - val_mae: 1.7970
# Epoch 28/120
# 192/192 [==============================] - 1s 5ms/step - loss: 8.3491 - mae: 1.7322 - val_loss: 14.4911 - val_mae: 1.8750
# Epoch 29/120
# 192/192 [==============================] - 1s 5ms/step - loss: 8.3471 - mae: 1.7571 - val_loss: 13.6024 - val_mae: 1.8017
# Epoch 30/120
# 192/192 [==============================] - 1s 5ms/step - loss: 8.3221 - mae: 1.7281 - val_loss: 13.5129 - val_mae: 1.8094
# Epoch 31/120
# 192/192 [==============================] - 1s 5ms/step - loss: 8.3051 - mae: 1.7465 - val_loss: 13.5717 - val_mae: 1.8234
# Epoch 32/120
# 192/192 [==============================] - 1s 5ms/step - loss: 8.2877 - mae: 1.7453 - val_loss: 13.6326 - val_mae: 1.7864
# Epoch 33/120
# 192/192 [==============================] - 1s 5ms/step - loss: 8.2812 - mae: 1.7263 - val_loss: 13.4959 - val_mae: 1.8224
# Epoch 34/120
# 192/192 [==============================] - 1s 5ms/step - loss: 8.2530 - mae: 1.7333 - val_loss: 13.9327 - val_mae: 1.8251
# Epoch 35/120
# 192/192 [==============================] - 1s 5ms/step - loss: 8.2504 - mae: 1.7344 - val_loss: 13.6469 - val_mae: 1.8071
# Epoch 36/120
# 192/192 [==============================] - 1s 5ms/step - loss: 8.2218 - mae: 1.7206 - val_loss: 13.5875 - val_mae: 1.8054
# Epoch 37/120
# 192/192 [==============================] - 1s 5ms/step - loss: 8.2359 - mae: 1.7272 - val_loss: 13.5375 - val_mae: 1.8189
# Epoch 38/120
# 192/192 [==============================] - 1s 5ms/step - loss: 8.2088 - mae: 1.7384 - val_loss: 13.6180 - val_mae: 1.8016
# Epoch 39/120
# 192/192 [==============================] - 1s 5ms/step - loss: 8.2064 - mae: 1.7236 - val_loss: 13.6289 - val_mae: 1.8227
# Epoch 40/120
# 192/192 [==============================] - 1s 5ms/step - loss: 8.1954 - mae: 1.7267 - val_loss: 13.5043 - val_mae: 1.8007
# Epoch 41/120
# 192/192 [==============================] - 1s 5ms/step - loss: 8.1857 - mae: 1.7243 - val_loss: 13.5434 - val_mae: 1.8048
# Epoch 42/120
# 192/192 [==============================] - 1s 5ms/step - loss: 8.1807 - mae: 1.7107 - val_loss: 13.5284 - val_mae: 1.8335
# Epoch 43/120
# 192/192 [==============================] - 1s 5ms/step - loss: 8.1669 - mae: 1.7319 - val_loss: 13.8497 - val_mae: 1.8145
# Epoch 44/120
# 192/192 [==============================] - 1s 5ms/step - loss: 8.1569 - mae: 1.7102 - val_loss: 13.4763 - val_mae: 1.8156
# Epoch 45/120
# 192/192 [==============================] - 1s 5ms/step - loss: 8.1203 - mae: 1.7158 - val_loss: 13.7825 - val_mae: 1.8120
# Epoch 46/120
# 192/192 [==============================] - 1s 5ms/step - loss: 8.1193 - mae: 1.7121 - val_loss: 13.6188 - val_mae: 1.8198
# Epoch 47/120
# 192/192 [==============================] - 1s 5ms/step - loss: 8.1012 - mae: 1.7149 - val_loss: 14.0561 - val_mae: 1.8122
# Epoch 48/120
# 192/192 [==============================] - 1s 5ms/step - loss: 8.1689 - mae: 1.7225 - val_loss: 13.6196 - val_mae: 1.7761
# Epoch 49/120
# 192/192 [==============================] - 1s 5ms/step - loss: 8.0835 - mae: 1.7040 - val_loss: 13.5391 - val_mae: 1.8018
# Epoch 50/120
# 192/192 [==============================] - 1s 5ms/step - loss: 8.0831 - mae: 1.7109 - val_loss: 13.4452 - val_mae: 1.8048
# Epoch 51/120
# 192/192 [==============================] - 1s 5ms/step - loss: 8.0590 - mae: 1.7073 - val_loss: 13.8778 - val_mae: 1.8155
# Epoch 52/120
# 192/192 [==============================] - 1s 5ms/step - loss: 8.0348 - mae: 1.7225 - val_loss: 14.1990 - val_mae: 1.7932
# Epoch 53/120
# 192/192 [==============================] - 1s 5ms/step - loss: 8.0610 - mae: 1.7078 - val_loss: 13.7710 - val_mae: 1.8163
# Epoch 54/120
# 192/192 [==============================] - 1s 5ms/step - loss: 8.0477 - mae: 1.7102 - val_loss: 13.8283 - val_mae: 1.7946
# Epoch 55/120
# 192/192 [==============================] - 1s 5ms/step - loss: 8.0110 - mae: 1.7084 - val_loss: 14.0434 - val_mae: 1.7972
# Epoch 56/120
# 192/192 [==============================] - 1s 5ms/step - loss: 7.9845 - mae: 1.6937 - val_loss: 13.8351 - val_mae: 1.8478
# Epoch 57/120
# 192/192 [==============================] - 1s 5ms/step - loss: 8.0293 - mae: 1.7182 - val_loss: 13.7173 - val_mae: 1.7897
# Epoch 58/120
# 192/192 [==============================] - 1s 5ms/step - loss: 7.9460 - mae: 1.6976 - val_loss: 13.8315 - val_mae: 1.8127
# Epoch 59/120
# 192/192 [==============================] - 1s 5ms/step - loss: 7.9416 - mae: 1.6995 - val_loss: 13.3973 - val_mae: 1.8008
# Epoch 60/120
# 192/192 [==============================] - 1s 5ms/step - loss: 7.9491 - mae: 1.7093 - val_loss: 13.7116 - val_mae: 1.7904
# Epoch 61/120
# 192/192 [==============================] - 1s 5ms/step - loss: 7.9604 - mae: 1.6993 - val_loss: 13.9684 - val_mae: 1.8185
# Epoch 62/120
# 192/192 [==============================] - 1s 5ms/step - loss: 7.8869 - mae: 1.7040 - val_loss: 13.7850 - val_mae: 1.8064
# Epoch 63/120
# 192/192 [==============================] - 1s 5ms/step - loss: 7.8669 - mae: 1.6940 - val_loss: 14.4678 - val_mae: 1.8927
# Epoch 64/120
# 192/192 [==============================] - 1s 5ms/step - loss: 7.8873 - mae: 1.7145 - val_loss: 14.1966 - val_mae: 1.8355
# Epoch 65/120
# 192/192 [==============================] - 1s 5ms/step - loss: 7.8592 - mae: 1.6868 - val_loss: 13.8107 - val_mae: 1.8626
# Epoch 66/120
# 192/192 [==============================] - 1s 5ms/step - loss: 7.8376 - mae: 1.7198 - val_loss: 14.4380 - val_mae: 1.8494
# Epoch 67/120
# 192/192 [==============================] - 1s 5ms/step - loss: 7.8601 - mae: 1.6843 - val_loss: 14.6488 - val_mae: 1.8828
# Epoch 68/120
# 192/192 [==============================] - 1s 5ms/step - loss: 7.9044 - mae: 1.7183 - val_loss: 13.8056 - val_mae: 1.8280
# Epoch 69/120
# 192/192 [==============================] - 1s 5ms/step - loss: 7.8215 - mae: 1.7062 - val_loss: 14.2506 - val_mae: 1.8292
# Epoch 70/120
# 192/192 [==============================] - 1s 5ms/step - loss: 7.9554 - mae: 1.6711 - val_loss: 14.3718 - val_mae: 1.8697
# Epoch 71/120
# 192/192 [==============================] - 1s 5ms/step - loss: 7.9269 - mae: 1.7067 - val_loss: 13.3536 - val_mae: 1.7930
# Epoch 72/120
# 192/192 [==============================] - 1s 5ms/step - loss: 7.8234 - mae: 1.7138 - val_loss: 13.9699 - val_mae: 1.8309
# Epoch 73/120
# 192/192 [==============================] - 1s 5ms/step - loss: 7.8132 - mae: 1.6975 - val_loss: 14.1455 - val_mae: 1.8234
# Epoch 74/120
# 192/192 [==============================] - 1s 5ms/step - loss: 7.7160 - mae: 1.6754 - val_loss: 14.1126 - val_mae: 1.8566
# Epoch 75/120
# 192/192 [==============================] - 1s 5ms/step - loss: 7.7418 - mae: 1.7046 - val_loss: 14.1332 - val_mae: 1.8423
# Epoch 76/120
# 192/192 [==============================] - 1s 5ms/step - loss: 7.7427 - mae: 1.7042 - val_loss: 14.2015 - val_mae: 1.8177
# Epoch 77/120
# 192/192 [==============================] - 1s 5ms/step - loss: 8.0204 - mae: 1.7487 - val_loss: 14.2278 - val_mae: 1.8469
# Epoch 78/120
# 192/192 [==============================] - 1s 5ms/step - loss: 7.7700 - mae: 1.6889 - val_loss: 14.0049 - val_mae: 1.8306
# Epoch 79/120
# 192/192 [==============================] - 1s 5ms/step - loss: 7.7100 - mae: 1.6867 - val_loss: 14.4245 - val_mae: 1.8358
# Epoch 80/120
# 192/192 [==============================] - 1s 5ms/step - loss: 7.7319 - mae: 1.6796 - val_loss: 14.3460 - val_mae: 1.8396
# Epoch 81/120
# 192/192 [==============================] - 1s 5ms/step - loss: 7.6269 - mae: 1.6793 - val_loss: 14.2606 - val_mae: 1.8374
# Epoch 82/120
# 192/192 [==============================] - 1s 5ms/step - loss: 7.6093 - mae: 1.6815 - val_loss: 14.6883 - val_mae: 1.8341
# Epoch 83/120
# 192/192 [==============================] - 1s 5ms/step - loss: 7.5403 - mae: 1.6825 - val_loss: 14.9984 - val_mae: 1.9055
# Epoch 84/120
# 192/192 [==============================] - 1s 5ms/step - loss: 7.7627 - mae: 1.7077 - val_loss: 14.4822 - val_mae: 1.8776
# Epoch 85/120
# 192/192 [==============================] - 1s 5ms/step - loss: 7.6863 - mae: 1.7072 - val_loss: 14.1297 - val_mae: 1.8315
# Epoch 86/120
# 192/192 [==============================] - 1s 5ms/step - loss: 7.6532 - mae: 1.6852 - val_loss: 14.5763 - val_mae: 1.8933
# Epoch 1/120
# 192/192 [==============================] - 4s 10ms/step - loss: 11.8913 - mae: 2.1544 - val_loss: 18.5821 - val_mae: 2.2849
# Epoch 2/120
# 192/192 [==============================] - 1s 7ms/step - loss: 10.3596 - mae: 2.0614 - val_loss: 16.5435 - val_mae: 2.2219
# Epoch 3/120
# 192/192 [==============================] - 1s 7ms/step - loss: 9.4334 - mae: 1.9528 - val_loss: 15.1512 - val_mae: 2.0309
# Epoch 4/120
# 192/192 [==============================] - 1s 7ms/step - loss: 8.9453 - mae: 1.8791 - val_loss: 14.7202 - val_mae: 2.0131
# Epoch 5/120
# 192/192 [==============================] - 1s 7ms/step - loss: 8.7645 - mae: 1.8561 - val_loss: 14.3798 - val_mae: 1.8674
# Epoch 6/120
# 192/192 [==============================] - 1s 7ms/step - loss: 8.6387 - mae: 1.8106 - val_loss: 14.4707 - val_mae: 1.8933
# Epoch 7/120
# 192/192 [==============================] - 1s 7ms/step - loss: 8.5900 - mae: 1.7826 - val_loss: 14.2842 - val_mae: 1.9002
# Epoch 8/120
# 192/192 [==============================] - 1s 7ms/step - loss: 8.5243 - mae: 1.7841 - val_loss: 14.3268 - val_mae: 1.8116
# Epoch 9/120
# 192/192 [==============================] - 1s 7ms/step - loss: 8.4850 - mae: 1.7575 - val_loss: 14.1829 - val_mae: 1.8278
# Epoch 10/120
# 192/192 [==============================] - 1s 7ms/step - loss: 8.4608 - mae: 1.7433 - val_loss: 14.1337 - val_mae: 1.9146
# Epoch 11/120
# 192/192 [==============================] - 1s 7ms/step - loss: 8.4399 - mae: 1.7605 - val_loss: 14.1033 - val_mae: 1.7772
# Epoch 12/120
# 192/192 [==============================] - 1s 7ms/step - loss: 8.4311 - mae: 1.7355 - val_loss: 14.4490 - val_mae: 1.8051
# Epoch 13/120
# 192/192 [==============================] - 1s 7ms/step - loss: 8.4016 - mae: 1.7474 - val_loss: 13.8749 - val_mae: 1.7808
# Epoch 14/120
# 192/192 [==============================] - 1s 7ms/step - loss: 8.3570 - mae: 1.7451 - val_loss: 13.9915 - val_mae: 1.7684
# Epoch 15/120
# 192/192 [==============================] - 1s 7ms/step - loss: 8.3650 - mae: 1.7374 - val_loss: 13.9484 - val_mae: 1.7860
# Epoch 16/120
# 192/192 [==============================] - 1s 7ms/step - loss: 8.3226 - mae: 1.7369 - val_loss: 13.9252 - val_mae: 1.8354
# Epoch 17/120
# 192/192 [==============================] - 1s 7ms/step - loss: 8.2952 - mae: 1.7239 - val_loss: 13.7505 - val_mae: 1.8082
# Epoch 18/120
# 192/192 [==============================] - 1s 7ms/step - loss: 8.2770 - mae: 1.7302 - val_loss: 13.9791 - val_mae: 1.7818
# Epoch 19/120
# ...
# Epoch 2/120
# 193/193 [==============================] - 2s 8ms/step - loss: 3.4336 - mae: 1.3076 - val_loss: 7.1080 - val_mae: 1.3345
# Epoch 3/120
# 193/193 [==============================] - 1s 8ms/step - loss: 1.7192 - mae: 0.8377 - val_loss: 5.1422 - val_mae: 0.9279
# Epoch 4/120
# 193/193 [==============================] - 1s 8ms/step - loss: 0.9718 - mae: 0.5467 - val_loss: 4.2264 - val_mae: 0.7451
# Epoch 5/120
# 193/193 [==============================] - 1s 8ms/step - loss: 0.6542 - mae: 0.4138 - val_loss: 3.7067 - val_mae: 0.5736
# Epoch 6/120
# 193/193 [==============================] - 1s 8ms/step - loss: 0.5009 - mae: 0.3532 - val_loss: 3.3424 - val_mae: 0.5262
# Epoch 7/120
# 193/193 [==============================] - 1s 7ms/step - loss: 0.4088 - mae: 0.3133 - val_loss: 3.0977 - val_mae: 0.5151
# Epoch 8/120
# 193/193 [==============================] - 1s 8ms/step - loss: 0.3631 - mae: 0.3009 - val_loss: 2.8985 - val_mae: 0.4766
# Epoch 9/120
# 193/193 [==============================] - 1s 8ms/step - loss: 0.3132 - mae: 0.2870 - val_loss: 2.7320 - val_mae: 0.5003
# Epoch 10/120
# 193/193 [==============================] - 1s 8ms/step - loss: 0.2847 - mae: 0.2807 - val_loss: 2.5815 - val_mae: 0.4600
# Epoch 11/120
# 193/193 [==============================] - 1s 8ms/step - loss: 0.2526 - mae: 0.2668 - val_loss: 2.4389 - val_mae: 0.4674
# Epoch 12/120
# 193/193 [==============================] - 2s 8ms/step - loss: 0.2253 - mae: 0.2584 - val_loss: 2.2726 - val_mae: 0.4121
# Epoch 13/120
# 193/193 [==============================] - 1s 7ms/step - loss: 0.2014 - mae: 0.2427 - val_loss: 2.1778 - val_mae: 0.4707
# Epoch 14/120
# 193/193 [==============================] - 1s 8ms/step - loss: 0.1864 - mae: 0.2387 - val_loss: 2.0543 - val_mae: 0.4192
# Epoch 15/120
# 193/193 [==============================] - 1s 8ms/step - loss: 0.1728 - mae: 0.2395 - val_loss: 1.9328 - val_mae: 0.3766
# Epoch 16/120
# 193/193 [==============================] - 1s 8ms/step - loss: 0.1612 - mae: 0.2322 - val_loss: 1.8659 - val_mae: 0.3702
# Epoch 17/120
# 193/193 [==============================] - 1s 8ms/step - loss: 0.1511 - mae: 0.2291 - val_loss: 1.7849 - val_mae: 0.3855
# Epoch 18/120
# 193/193 [==============================] - 1s 8ms/step - loss: 0.1396 - mae: 0.2202 - val_loss: 1.7192 - val_mae: 0.4160
# Epoch 19/120
# 193/193 [==============================] - 2s 8ms/step - loss: 0.1365 - mae: 0.2296 - val_loss: 1.6314 - val_mae: 0.3640
# Epoch 20/120
# 193/193 [==============================] - 1s 8ms/step - loss: 0.1276 - mae: 0.2169 - val_loss: 1.5639 - val_mae: 0.3499
# Epoch 21/120
# 193/193 [==============================] - 1s 8ms/step - loss: 0.1161 - mae: 0.2053 - val_loss: 1.5140 - val_mae: 0.3412
# Epoch 22/120
# 193/193 [==============================] - 1s 7ms/step - loss: 0.1161 - mae: 0.2091 - val_loss: 1.4623 - val_mae: 0.3271
# Epoch 23/120
# 193/193 [==============================] - 1s 7ms/step - loss: 0.1106 - mae: 0.2033 - val_loss: 1.4111 - val_mae: 0.3368
# Epoch 24/120
# 193/193 [==============================] - 1s 8ms/step - loss: 0.1037 - mae: 0.1988 - val_loss: 1.3810 - val_mae: 0.3656
# Epoch 25/120
# 193/193 [==============================] - 1s 8ms/step - loss: 0.1010 - mae: 0.2008 - val_loss: 1.3405 - val_mae: 0.3185
# Epoch 26/120
# 193/193 [==============================] - 1s 8ms/step - loss: 0.1020 - mae: 0.2034 - val_loss: 1.2838 - val_mae: 0.3505
# Epoch 27/120
# 193/193 [==============================] - 1s 8ms/step - loss: 0.0974 - mae: 0.2002 - val_loss: 1.2371 - val_mae: 0.3218
# Epoch 28/120
# 193/193 [==============================] - 2s 8ms/step - loss: 0.0906 - mae: 0.1929 - val_loss: 1.1955 - val_mae: 0.3037
# Epoch 29/120
# 193/193 [==============================] - 2s 8ms/step - loss: 0.0889 - mae: 0.1937 - val_loss: 1.1593 - val_mae: 0.2980
# Epoch 30/120
# 193/193 [==============================] - 2s 8ms/step - loss: 0.0871 - mae: 0.1965 - val_loss: 1.1403 - val_mae: 0.3053
# Epoch 31/120
# 193/193 [==============================] - 2s 8ms/step - loss: 0.0855 - mae: 0.1913 - val_loss: 1.1058 - val_mae: 0.3005
# Epoch 32/120
# 193/193 [==============================] - 2s 8ms/step - loss: 0.0795 - mae: 0.1832 - val_loss: 1.0723 - val_mae: 0.3038
# Epoch 33/120
# 193/193 [==============================] - 2s 8ms/step - loss: 0.0764 - mae: 0.1832 - val_loss: 1.0490 - val_mae: 0.3034
# Epoch 34/120
# 193/193 [==============================] - 2s 8ms/step - loss: 0.0832 - mae: 0.1869 - val_loss: 1.0242 - val_mae: 0.2908
# Epoch 35/120
# 193/193 [==============================] - 2s 8ms/step - loss: 0.0773 - mae: 0.1883 - val_loss: 0.9999 - val_mae: 0.3238
# Epoch 36/120
# 193/193 [==============================] - 1s 8ms/step - loss: 0.0735 - mae: 0.1826 - val_loss: 0.9669 - val_mae: 0.3059
# Epoch 37/120
# 193/193 [==============================] - 1s 8ms/step - loss: 0.0801 - mae: 0.1910 - val_loss: 0.9686 - val_mae: 0.2881
# Epoch 38/120
# 193/193 [==============================] - 1s 8ms/step - loss: 0.0775 - mae: 0.1889 - val_loss: 0.9405 - val_mae: 0.2867
# Epoch 39/120
# 193/193 [==============================] - 1s 8ms/step - loss: 0.0731 - mae: 0.1851 - val_loss: 0.9183 - val_mae: 0.2841
# Epoch 40/120
# 193/193 [==============================] - 1s 8ms/step - loss: 0.0706 - mae: 0.1805 - val_loss: 0.9078 - val_mae: 0.2954
# Epoch 41/120
# 193/193 [==============================] - 1s 8ms/step - loss: 0.0693 - mae: 0.1760 - val_loss: 0.8871 - val_mae: 0.3106
# Epoch 42/120
# 193/193 [==============================] - 2s 8ms/step - loss: 0.0689 - mae: 0.1739 - val_loss: 0.8631 - val_mae: 0.2775
# Epoch 43/120
# 193/193 [==============================] - 1s 8ms/step - loss: 0.0678 - mae: 0.1779 - val_loss: 0.8649 - val_mae: 0.2778
# Epoch 44/120
# 193/193 [==============================] - 1s 8ms/step - loss: 0.0675 - mae: 0.1769 - val_loss: 0.8357 - val_mae: 0.3038
# Epoch 45/120
# 193/193 [==============================] - 1s 8ms/step - loss: 0.0772 - mae: 0.1859 - val_loss: 0.8489 - val_mae: 0.2943
# Epoch 46/120
# 193/193 [==============================] - 1s 7ms/step - loss: 0.0705 - mae: 0.1785 - val_loss: 0.8075 - val_mae: 0.2964
# Epoch 47/120
# 193/193 [==============================] - 1s 8ms/step - loss: 0.0688 - mae: 0.1812 - val_loss: 0.7889 - val_mae: 0.2859
# Epoch 48/120
# 193/193 [==============================] - 1s 8ms/step - loss: 0.0620 - mae: 0.1679 - val_loss: 0.7951 - val_mae: 0.2987
# Epoch 49/120
# 193/193 [==============================] - 2s 8ms/step - loss: 0.0659 - mae: 0.1736 - val_loss: 0.7696 - val_mae: 0.2789
# Epoch 50/120
# 193/193 [==============================] - 2s 8ms/step - loss: 0.0684 - mae: 0.1757 - val_loss: 0.7698 - val_mae: 0.2713
# Epoch 51/120
# 193/193 [==============================] - 1s 8ms/step - loss: 0.0616 - mae: 0.1711 - val_loss: 0.7518 - val_mae: 0.2748
# Epoch 52/120
# 193/193 [==============================] - 2s 8ms/step - loss: 0.0658 - mae: 0.1752 - val_loss: 0.7505 - val_mae: 0.2678
# Epoch 53/120
# 193/193 [==============================] - 1s 8ms/step - loss: 0.0625 - mae: 0.1705 - val_loss: 0.7606 - val_mae: 0.2807
# Epoch 54/120
# 193/193 [==============================] - 1s 8ms/step - loss: 0.0635 - mae: 0.1740 - val_loss: 0.7365 - val_mae: 0.2666
# Epoch 55/120
# 193/193 [==============================] - 1s 8ms/step - loss: 0.0678 - mae: 0.1798 - val_loss: 0.7300 - val_mae: 0.2719
# Epoch 56/120
# 193/193 [==============================] - 1s 8ms/step - loss: 0.0651 - mae: 0.1753 - val_loss: 0.7332 - val_mae: 0.2772
# Epoch 57/120
# 193/193 [==============================] - 2s 8ms/step - loss: 0.0639 - mae: 0.1744 - val_loss: 0.7060 - val_mae: 0.2701
# Epoch 58/120
# 193/193 [==============================] - 2s 8ms/step - loss: 0.0630 - mae: 0.1702 - val_loss: 0.7240 - val_mae: 0.2660
# Epoch 59/120
# 193/193 [==============================] - 2s 8ms/step - loss: 0.0607 - mae: 0.1677 - val_loss: 0.6947 - val_mae: 0.2660
# Epoch 60/120
# 193/193 [==============================] - 2s 8ms/step - loss: 0.0604 - mae: 0.1674 - val_loss: 0.6927 - val_mae: 0.2681
# Epoch 61/120
# 193/193 [==============================] - 1s 8ms/step - loss: 0.0609 - mae: 0.1722 - val_loss: 0.6902 - val_mae: 0.2532
# Epoch 62/120
# 193/193 [==============================] - 1s 8ms/step - loss: 0.0587 - mae: 0.1655 - val_loss: 0.6902 - val_mae: 0.2782
# Epoch 63/120
# 193/193 [==============================] - 1s 7ms/step - loss: 0.0618 - mae: 0.1740 - val_loss: 0.6982 - val_mae: 0.2911
# Epoch 64/120
# 193/193 [==============================] - 2s 8ms/step - loss: 0.0661 - mae: 0.1786 - val_loss: 0.6729 - val_mae: 0.2577
# Epoch 65/120
# 193/193 [==============================] - 1s 8ms/step - loss: 0.0586 - mae: 0.1653 - val_loss: 0.6837 - val_mae: 0.2759
# Epoch 66/120
# 193/193 [==============================] - 2s 8ms/step - loss: 0.0583 - mae: 0.1638 - val_loss: 0.7045 - val_mae: 0.2984
# Epoch 67/120
# 193/193 [==============================] - 1s 8ms/step - loss: 0.0576 - mae: 0.1673 - val_loss: 0.6642 - val_mae: 0.2727
# Epoch 68/120
# 193/193 [==============================] - 1s 7ms/step - loss: 0.0593 - mae: 0.1660 - val_loss: 0.6566 - val_mae: 0.2562
# Epoch 69/120
# 193/193 [==============================] - 1s 8ms/step - loss: 0.0588 - mae: 0.1695 - val_loss: 0.6701 - val_mae: 0.2622
# Epoch 70/120
# 193/193 [==============================] - 1s 8ms/step - loss: 0.0590 - mae: 0.1681 - val_loss: 0.6810 - val_mae: 0.2769
# Epoch 71/120
# 193/193 [==============================] - 1s 8ms/step - loss: 0.0608 - mae: 0.1715 - val_loss: 0.6436 - val_mae: 0.2713
# Epoch 72/120
# 193/193 [==============================] - 2s 8ms/step - loss: 0.0613 - mae: 0.1718 - val_loss: 0.6994 - val_mae: 0.2836
# Epoch 73/120
# 193/193 [==============================] - 2s 8ms/step - loss: 0.0606 - mae: 0.1686 - val_loss: 0.6674 - val_mae: 0.2607
# Epoch 74/120
# 193/193 [==============================] - 1s 8ms/step - loss: 0.0591 - mae: 0.1702 - val_loss: 0.6517 - val_mae: 0.2665
# Epoch 75/120
# 193/193 [==============================] - 2s 8ms/step - loss: 0.0589 - mae: 0.1656 - val_loss: 0.6897 - val_mae: 0.2919
# Epoch 76/120
# 193/193 [==============================] - 2s 8ms/step - loss: 0.0665 - mae: 0.1766 - val_loss: 0.6374 - val_mae: 0.2551
# Epoch 77/120
# 193/193 [==============================] - 2s 8ms/step - loss: 0.0591 - mae: 0.1685 - val_loss: 0.6363 - val_mae: 0.2509
# Epoch 78/120
# 193/193 [==============================] - 1s 8ms/step - loss: 0.0579 - mae: 0.1657 - val_loss: 0.6396 - val_mae: 0.2732
# Epoch 79/120
# 193/193 [==============================] - 1s 8ms/step - loss: 0.0560 - mae: 0.1613 - val_loss: 0.6350 - val_mae: 0.2550
# Epoch 80/120
# 193/193 [==============================] - 2s 8ms/step - loss: 0.0561 - mae: 0.1658 - val_loss: 0.6359 - val_mae: 0.2539
# Epoch 81/120
# 193/193 [==============================] - 1s 8ms/step - loss: 0.0549 - mae: 0.1609 - val_loss: 0.6425 - val_mae: 0.2689
# Epoch 82/120
# 193/193 [==============================] - 1s 8ms/step - loss: 0.0586 - mae: 0.1679 - val_loss: 0.6493 - val_mae: 0.2596
# Epoch 83/120
# 193/193 [==============================] - 2s 8ms/step - loss: 0.0602 - mae: 0.1702 - val_loss: 0.6293 - val_mae: 0.2505
# Epoch 84/120
# 193/193 [==============================] - 1s 8ms/step - loss: 0.0546 - mae: 0.1600 - val_loss: 0.6606 - val_mae: 0.2627
# Epoch 85/120
# 193/193 [==============================] - 1s 8ms/step - loss: 0.0573 - mae: 0.1693 - val_loss: 0.6672 - val_mae: 0.2570
# Epoch 86/120
# 193/193 [==============================] - 2s 8ms/step - loss: 0.0558 - mae: 0.1628 - val_loss: 0.6489 - val_mae: 0.3262
# Epoch 87/120
# 193/193 [==============================] - 2s 8ms/step - loss: 0.0566 - mae: 0.1658 - val_loss: 0.6433 - val_mae: 0.2674
# Epoch 88/120
# 193/193 [==============================] - 2s 8ms/step - loss: 0.0563 - mae: 0.1663 - val_loss: 0.6214 - val_mae: 0.2839
# Epoch 89/120
# 193/193 [==============================] - 2s 8ms/step - loss: 0.0560 - mae: 0.1656 - val_loss: 0.6358 - val_mae: 0.3108
# Epoch 90/120
# 193/193 [==============================] - 1s 8ms/step - loss: 0.0521 - mae: 0.1586 - val_loss: 0.6224 - val_mae: 0.2588
# Epoch 91/120
# 193/193 [==============================] - 2s 8ms/step - loss: 0.0531 - mae: 0.1605 - val_loss: 0.6354 - val_mae: 0.2774
# Epoch 92/120
# 193/193 [==============================] - 1s 8ms/step - loss: 0.0553 - mae: 0.1631 - val_loss: 0.6299 - val_mae: 0.2802
# Epoch 93/120
# 193/193 [==============================] - 1s 8ms/step - loss: 0.0575 - mae: 0.1671 - val_loss: 0.6172 - val_mae: 0.2626
# Epoch 94/120
# 193/193 [==============================] - 2s 8ms/step - loss: 0.0555 - mae: 0.1619 - val_loss: 0.6020 - val_mae: 0.2777
# Epoch 95/120
# 193/193 [==============================] - 2s 8ms/step - loss: 0.0553 - mae: 0.1608 - val_loss: 0.6358 - val_mae: 0.2601
# Epoch 96/120
# 193/193 [==============================] - 2s 8ms/step - loss: 0.0525 - mae: 0.1578 - val_loss: 0.5812 - val_mae: 0.2475
# Epoch 97/120
# 193/193 [==============================] - 1s 7ms/step - loss: 0.0577 - mae: 0.1686 - val_loss: 0.6175 - val_mae: 0.2642
# Epoch 98/120
# 193/193 [==============================] - 1s 8ms/step - loss: 0.0651 - mae: 0.1770 - val_loss: 0.6116 - val_mae: 0.2651
# Epoch 99/120
# 193/193 [==============================] - 1s 8ms/step - loss: 0.0521 - mae: 0.1576 - val_loss: 0.5784 - val_mae: 0.2442
# Epoch 100/120
# 193/193 [==============================] - 1s 7ms/step - loss: 0.0508 - mae: 0.1571 - val_loss: 0.5944 - val_mae: 0.2764
# Epoch 101/120
# 193/193 [==============================] - 1s 8ms/step - loss: 0.0573 - mae: 0.1683 - val_loss: 0.6201 - val_mae: 0.2804
# Epoch 102/120
# 193/193 [==============================] - 1s 8ms/step - loss: 0.0559 - mae: 0.1654 - val_loss: 0.6208 - val_mae: 0.2537
# Epoch 103/120
# 193/193 [==============================] - 2s 8ms/step - loss: 0.0546 - mae: 0.1637 - val_loss: 0.6119 - val_mae: 0.2441
# Epoch 104/120
# 193/193 [==============================] - 1s 8ms/step - loss: 0.0592 - mae: 0.1678 - val_loss: 0.5710 - val_mae: 0.2521
# Epoch 105/120
# 193/193 [==============================] - 1s 8ms/step - loss: 0.0556 - mae: 0.1645 - val_loss: 0.6045 - val_mae: 0.2592
# Epoch 106/120
# 193/193 [==============================] - 1s 8ms/step - loss: 0.0499 - mae: 0.1572 - val_loss: 0.5879 - val_mae: 0.2460
# Epoch 107/120
# 193/193 [==============================] - 2s 8ms/step - loss: 0.0549 - mae: 0.1631 - val_loss: 0.5567 - val_mae: 0.2482
# Epoch 108/120
# 193/193 [==============================] - 1s 8ms/step - loss: 0.0527 - mae: 0.1600 - val_loss: 0.5818 - val_mae: 0.2967
# Epoch 109/120
# 193/193 [==============================] - 1s 8ms/step - loss: 0.0518 - mae: 0.1603 - val_loss: 0.5776 - val_mae: 0.2739
# Epoch 110/120
# 193/193 [==============================] - 2s 8ms/step - loss: 0.0534 - mae: 0.1641 - val_loss: 0.5907 - val_mae: 0.2464
# Epoch 111/120
# 193/193 [==============================] - 1s 8ms/step - loss: 0.0537 - mae: 0.1615 - val_loss: 0.5700 - val_mae: 0.2654
# Epoch 112/120
# 193/193 [==============================] - 2s 8ms/step - loss: 0.0513 - mae: 0.1605 - val_loss: 0.5929 - val_mae: 0.2410
# Epoch 113/120
# 193/193 [==============================] - 1s 8ms/step - loss: 0.0546 - mae: 0.1646 - val_loss: 0.5676 - val_mae: 0.2427
# Epoch 114/120
# 193/193 [==============================] - 2s 8ms/step - loss: 0.0537 - mae: 0.1612 - val_loss: 0.5956 - val_mae: 0.2964
# Epoch 115/120
# 193/193 [==============================] - 2s 8ms/step - loss: 0.0554 - mae: 0.1628 - val_loss: 0.6025 - val_mae: 0.2529
# Epoch 116/120
# 193/193 [==============================] - 1s 8ms/step - loss: 0.0566 - mae: 0.1661 - val_loss: 0.5894 - val_mae: 0.2639
# Epoch 117/120
# 193/193 [==============================] - 1s 8ms/step - loss: 0.0523 - mae: 0.1593 - val_loss: 0.5981 - val_mae: 0.2654
# Epoch 118/120
# 193/193 [==============================] - 2s 8ms/step - loss: 0.0540 - mae: 0.1659 - val_loss: 0.5927 - val_mae: 0.2421
# Epoch 119/120
# 193/193 [==============================] - 2s 8ms/step - loss: 0.0513 - mae: 0.1597 - val_loss: 0.5911 - val_mae: 0.2475
# Epoch 120/120
# 193/193 [==============================] - 2s 8ms/step - loss: 0.0481 - mae: 0.1535 - val_loss: 0.5799 - val_mae: 0.2720

# %% [markdown]
# ## Analyse the Grid Search Results

# %%
#load it from drive
records = pd.read_csv('records_1621964476.csv')
records2 = pd.read_csv('records_1621964569.csv')

gs = pd.concat([records,records2])

# %%
gs.groupby('length')['val_mae_og'].mean().plot(kind='bar', title='mean'); plt.show()
gs.groupby('layers_num')['val_mae_og'].mean().plot(kind='bar', title='mean'); plt.show()
gs.groupby('layers_type')['val_mae_og'].mean().plot(kind='bar', title='mean'); plt.show()
gs.groupby('units')['val_mae_og'].mean().plot(kind='bar', title='mean'); plt.show()
gs.groupby('g_filt')['val_mae_og'].mean().plot(kind='bar', title='mean'); plt.show()

# %% [markdown]
# COMMENTARY
#
# Not too disimlar to the temp model, though it does better with another recurrent layer.

# %% [markdown]
# ## Recreate the best model and compare against test data

# %%
best_model_params = gs.sort_values('val_mae_og').iloc[0]
best_model_params
# Out:
# length              30
# layers_num           2
# layers_type       LSTM
# units               40
# g_filt               1
# val_mae_og     1.40854
# Name: 11, dtype: object

# %%
best_model = BuildModel(model_name='best_precip_model.h5', length=30, layers_num=2,\
                        layers_type='LSTM', units=40, dropout=0, g_filt=1, epochs=120, batch_size=10,\
                        patience=15)

best_model.setupData(precip_train)
best_model.fitModel()
# Out:
# Epoch 1/120
# 192/192 [==============================] - 10s 9ms/step - loss: 5.9265 - mae: 1.7318 - val_loss: 9.4089 - val_mae: 1.7684
# Epoch 2/120
# 192/192 [==============================] - 1s 6ms/step - loss: 2.3797 - mae: 1.0141 - val_loss: 4.8487 - val_mae: 1.0005
# Epoch 3/120
# 192/192 [==============================] - 1s 6ms/step - loss: 1.0093 - mae: 0.6113 - val_loss: 3.6848 - val_mae: 0.7233
# Epoch 4/120
# 192/192 [==============================] - 1s 6ms/step - loss: 0.7683 - mae: 0.5344 - val_loss: 3.1916 - val_mae: 0.6513
# Epoch 5/120
# 192/192 [==============================] - 1s 6ms/step - loss: 0.6468 - mae: 0.4969 - val_loss: 2.9017 - val_mae: 0.6739
# Epoch 6/120
# 192/192 [==============================] - 1s 6ms/step - loss: 0.6015 - mae: 0.4852 - val_loss: 2.6636 - val_mae: 0.6715
# Epoch 7/120
# 192/192 [==============================] - 1s 6ms/step - loss: 0.5509 - mae: 0.4696 - val_loss: 2.5409 - val_mae: 0.6035
# Epoch 8/120
# 192/192 [==============================] - 1s 6ms/step - loss: 0.5511 - mae: 0.4801 - val_loss: 2.2780 - val_mae: 0.5558
# Epoch 9/120
# 192/192 [==============================] - 1s 6ms/step - loss: 0.5003 - mae: 0.4541 - val_loss: 2.2142 - val_mae: 0.6346
# Epoch 10/120
# 192/192 [==============================] - 1s 6ms/step - loss: 0.5062 - mae: 0.4635 - val_loss: 2.1476 - val_mae: 0.5365
# Epoch 11/120
# 192/192 [==============================] - 1s 6ms/step - loss: 0.4688 - mae: 0.4379 - val_loss: 2.0353 - val_mae: 0.6586
# Epoch 12/120
# 192/192 [==============================] - 1s 6ms/step - loss: 0.4578 - mae: 0.4382 - val_loss: 1.9215 - val_mae: 0.5441
# Epoch 13/120
# 192/192 [==============================] - 1s 6ms/step - loss: 0.4627 - mae: 0.4490 - val_loss: 1.8430 - val_mae: 0.5131
# Epoch 14/120
# 192/192 [==============================] - 1s 6ms/step - loss: 0.4457 - mae: 0.4443 - val_loss: 1.8452 - val_mae: 0.6347
# Epoch 15/120
# 192/192 [==============================] - 1s 6ms/step - loss: 0.4454 - mae: 0.4409 - val_loss: 1.7805 - val_mae: 0.4983
# Epoch 16/120
# 192/192 [==============================] - 1s 6ms/step - loss: 0.4196 - mae: 0.4232 - val_loss: 1.6937 - val_mae: 0.5247
# Epoch 17/120
# 192/192 [==============================] - 1s 6ms/step - loss: 0.4158 - mae: 0.4160 - val_loss: 1.6438 - val_mae: 0.5616
# Epoch 18/120
# 192/192 [==============================] - 1s 6ms/step - loss: 0.4064 - mae: 0.4180 - val_loss: 1.6306 - val_mae: 0.5622
# Epoch 19/120
# 192/192 [==============================] - 1s 6ms/step - loss: 0.3979 - mae: 0.4251 - val_loss: 1.6354 - val_mae: 0.5973
# Epoch 20/120
# 192/192 [==============================] - 1s 6ms/step - loss: 0.3947 - mae: 0.4137 - val_loss: 1.6346 - val_mae: 0.4917
# Epoch 21/120
# 192/192 [==============================] - 1s 6ms/step - loss: 0.3925 - mae: 0.4124 - val_loss: 1.5596 - val_mae: 0.5754
# Epoch 22/120
# 192/192 [==============================] - 1s 6ms/step - loss: 0.3860 - mae: 0.4122 - val_loss: 1.5617 - val_mae: 0.5389
# Epoch 23/120
# 192/192 [==============================] - 1s 6ms/step - loss: 0.3798 - mae: 0.4098 - val_loss: 1.4844 - val_mae: 0.5929
# Epoch 24/120
# 192/192 [==============================] - 1s 6ms/step - loss: 0.4002 - mae: 0.4222 - val_loss: 1.4344 - val_mae: 0.4653
# Epoch 25/120
# 192/192 [==============================] - 1s 6ms/step - loss: 0.3832 - mae: 0.4104 - val_loss: 1.4390 - val_mae: 0.5193
# Epoch 26/120
# 192/192 [==============================] - 1s 6ms/step - loss: 0.3811 - mae: 0.4090 - val_loss: 1.3823 - val_mae: 0.4851
# Epoch 27/120
# 192/192 [==============================] - 1s 6ms/step - loss: 0.3810 - mae: 0.4213 - val_loss: 1.4954 - val_mae: 0.5444
# Epoch 28/120
# 192/192 [==============================] - 1s 6ms/step - loss: 0.3708 - mae: 0.4040 - val_loss: 1.5262 - val_mae: 0.7085
# Epoch 29/120
# 192/192 [==============================] - 1s 6ms/step - loss: 0.3823 - mae: 0.4137 - val_loss: 1.3805 - val_mae: 0.5024
# Epoch 30/120
# 192/192 [==============================] - 1s 6ms/step - loss: 0.3629 - mae: 0.3949 - val_loss: 1.3724 - val_mae: 0.4711
# Epoch 31/120
# 192/192 [==============================] - 1s 6ms/step - loss: 0.3624 - mae: 0.3994 - val_loss: 1.3160 - val_mae: 0.4590
# Epoch 32/120
# 192/192 [==============================] - 1s 6ms/step - loss: 0.3554 - mae: 0.4024 - val_loss: 1.4084 - val_mae: 0.4676
# Epoch 33/120
# 192/192 [==============================] - 1s 6ms/step - loss: 0.3662 - mae: 0.3996 - val_loss: 1.3283 - val_mae: 0.5069
# Epoch 34/120
# 192/192 [==============================] - 1s 6ms/step - loss: 0.3740 - mae: 0.4030 - val_loss: 1.3238 - val_mae: 0.5468
# Epoch 35/120
# 192/192 [==============================] - 1s 6ms/step - loss: 0.3522 - mae: 0.3981 - val_loss: 1.4263 - val_mae: 0.4889
# Epoch 36/120
# 192/192 [==============================] - 1s 6ms/step - loss: 0.3546 - mae: 0.3949 - val_loss: 1.2848 - val_mae: 0.4743
# Epoch 37/120
# 192/192 [==============================] - 1s 6ms/step - loss: 0.3519 - mae: 0.3908 - val_loss: 1.2647 - val_mae: 0.4781
# Epoch 38/120
# 192/192 [==============================] - 1s 6ms/step - loss: 0.3493 - mae: 0.3924 - val_loss: 1.3926 - val_mae: 0.4761
# Epoch 39/120
# 192/192 [==============================] - 1s 6ms/step - loss: 0.3621 - mae: 0.3961 - val_loss: 1.3410 - val_mae: 0.4533
# Epoch 40/120
# 192/192 [==============================] - 1s 6ms/step - loss: 0.3469 - mae: 0.3992 - val_loss: 1.3526 - val_mae: 0.4746
# Epoch 41/120
# 192/192 [==============================] - 1s 6ms/step - loss: 0.3403 - mae: 0.3851 - val_loss: 1.2674 - val_mae: 0.4916
# Epoch 42/120
# 192/192 [==============================] - 1s 6ms/step - loss: 0.3651 - mae: 0.4037 - val_loss: 1.2786 - val_mae: 0.4749
# Epoch 43/120
# 192/192 [==============================] - 1s 6ms/step - loss: 0.3576 - mae: 0.4009 - val_loss: 1.2922 - val_mae: 0.5130
# Epoch 44/120
# 192/192 [==============================] - 1s 6ms/step - loss: 0.3461 - mae: 0.3955 - val_loss: 1.4128 - val_mae: 0.5210
# Epoch 45/120
# 192/192 [==============================] - 1s 6ms/step - loss: 0.3469 - mae: 0.3922 - val_loss: 1.3539 - val_mae: 0.4601
# Epoch 46/120
# 192/192 [==============================] - 1s 6ms/step - loss: 0.3408 - mae: 0.3939 - val_loss: 1.3132 - val_mae: 0.5211
# Epoch 47/120
# 192/192 [==============================] - 1s 6ms/step - loss: 0.3463 - mae: 0.3879 - val_loss: 1.3131 - val_mae: 0.4635
# Epoch 48/120
# 192/192 [==============================] - 1s 6ms/step - loss: 0.3446 - mae: 0.3907 - val_loss: 1.2989 - val_mae: 0.4524
# Epoch 49/120
# 192/192 [==============================] - 1s 6ms/step - loss: 0.3376 - mae: 0.3906 - val_loss: 1.2655 - val_mae: 0.5033
# Epoch 50/120
# 192/192 [==============================] - 1s 6ms/step - loss: 0.3263 - mae: 0.3824 - val_loss: 1.2141 - val_mae: 0.4687
# Epoch 51/120
# 192/192 [==============================] - 1s 6ms/step - loss: 0.3481 - mae: 0.4016 - val_loss: 1.3284 - val_mae: 0.4625
# Epoch 52/120
# 192/192 [==============================] - 1s 6ms/step - loss: 0.3325 - mae: 0.3874 - val_loss: 1.2453 - val_mae: 0.4784
# Epoch 53/120
# 192/192 [==============================] - 1s 6ms/step - loss: 0.3368 - mae: 0.3914 - val_loss: 1.3251 - val_mae: 0.5005
# Epoch 54/120
# 192/192 [==============================] - 1s 6ms/step - loss: 0.3483 - mae: 0.3884 - val_loss: 1.3476 - val_mae: 0.4650
# Epoch 55/120
# 192/192 [==============================] - 1s 6ms/step - loss: 0.3327 - mae: 0.3896 - val_loss: 1.2256 - val_mae: 0.4521
# Epoch 56/120
# 192/192 [==============================] - 1s 6ms/step - loss: 0.3126 - mae: 0.3780 - val_loss: 1.3066 - val_mae: 0.5173
# Epoch 57/120
# 192/192 [==============================] - 1s 6ms/step - loss: 0.3225 - mae: 0.3740 - val_loss: 1.3722 - val_mae: 0.4769
# Epoch 58/120
# 192/192 [==============================] - 1s 6ms/step - loss: 0.3257 - mae: 0.3799 - val_loss: 1.2217 - val_mae: 0.4619
# Epoch 59/120
# 192/192 [==============================] - 1s 6ms/step - loss: 0.3152 - mae: 0.3728 - val_loss: 1.2982 - val_mae: 0.4988
# Epoch 60/120
# 192/192 [==============================] - 1s 6ms/step - loss: 0.3242 - mae: 0.3865 - val_loss: 1.3443 - val_mae: 0.4680
# Epoch 61/120
# 192/192 [==============================] - 1s 6ms/step - loss: 0.3193 - mae: 0.3767 - val_loss: 1.3101 - val_mae: 0.5065
# Epoch 62/120
# 192/192 [==============================] - 1s 6ms/step - loss: 0.3135 - mae: 0.3824 - val_loss: 1.2799 - val_mae: 0.4888
# Epoch 63/120
# 192/192 [==============================] - 1s 6ms/step - loss: 0.2988 - mae: 0.3652 - val_loss: 1.2292 - val_mae: 0.4952
# Epoch 64/120
# 192/192 [==============================] - 1s 6ms/step - loss: 0.3155 - mae: 0.3727 - val_loss: 1.1919 - val_mae: 0.4558
# Epoch 65/120
# 192/192 [==============================] - 1s 6ms/step - loss: 0.3082 - mae: 0.3711 - val_loss: 1.2116 - val_mae: 0.5012
# Epoch 66/120
# 192/192 [==============================] - 1s 6ms/step - loss: 0.3038 - mae: 0.3731 - val_loss: 1.3188 - val_mae: 0.4651
# Epoch 67/120
# 192/192 [==============================] - 1s 6ms/step - loss: 0.2967 - mae: 0.3653 - val_loss: 1.2714 - val_mae: 0.4878
# Epoch 68/120
# 192/192 [==============================] - 1s 6ms/step - loss: 0.3018 - mae: 0.3674 - val_loss: 1.2643 - val_mae: 0.4599
# Epoch 69/120
# 192/192 [==============================] - 1s 6ms/step - loss: 0.3042 - mae: 0.3755 - val_loss: 1.5609 - val_mae: 0.5869
# Epoch 70/120
# 192/192 [==============================] - 1s 6ms/step - loss: 0.3320 - mae: 0.3857 - val_loss: 1.3554 - val_mae: 0.4905
# Epoch 71/120
# 192/192 [==============================] - 1s 6ms/step - loss: 0.3069 - mae: 0.3685 - val_loss: 1.2661 - val_mae: 0.4562
# Epoch 72/120
# 192/192 [==============================] - 1s 6ms/step - loss: 0.2862 - mae: 0.3591 - val_loss: 1.3191 - val_mae: 0.4822
# Epoch 73/120
# 192/192 [==============================] - 1s 6ms/step - loss: 0.2878 - mae: 0.3686 - val_loss: 1.2398 - val_mae: 0.4720
# Epoch 74/120
# 192/192 [==============================] - 1s 6ms/step - loss: 0.3007 - mae: 0.3696 - val_loss: 1.3216 - val_mae: 0.4751
# Epoch 75/120
# 192/192 [==============================] - 1s 7ms/step - loss: 0.2990 - mae: 0.3762 - val_loss: 1.3798 - val_mae: 0.5086
# Epoch 76/120
# 192/192 [==============================] - 1s 6ms/step - loss: 0.2922 - mae: 0.3593 - val_loss: 1.3084 - val_mae: 0.4791
# Epoch 77/120
# 192/192 [==============================] - 1s 6ms/step - loss: 0.2843 - mae: 0.3617 - val_loss: 1.2256 - val_mae: 0.4691
# Epoch 78/120
# 192/192 [==============================] - 1s 6ms/step - loss: 0.2894 - mae: 0.3618 - val_loss: 1.3116 - val_mae: 0.4678
# Epoch 79/120
# 192/192 [==============================] - 1s 6ms/step - loss: 0.2773 - mae: 0.3572 - val_loss: 1.2864 - val_mae: 0.4876

# %%
#load best performer
best_model.loadModel()

# %%
#predict a week
week_pred = best_model.predAhead(7)

#plot against test week
best_model.plotPreds(week_pred, precip_test, ylabel='precip')

# %% [markdown]
# COMMENTARY
#
# Harder to predict than temperature due to the somewhat binary nature of rain. It does or it doesnt. Though when it does then the question switches to:  how much will it rain?
